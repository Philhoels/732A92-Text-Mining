# %% [markdown]
# # L5: Information extraction

# %% [markdown]
# Information extraction (IE) is the task of identifying named entities and semantic relations between these entities in text data. In this lab we will focus on two sub-tasks in IE, **named entity recognition** (identifying mentions of entities) and **entity linking** (matching these mentions to entities in a knowledge base).

# %% [markdown]
# We start by loading spaCy:

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# The data that we will be using has been tokenized following the conventions of the [Penn Treebank](ftp://ftp.cis.upenn.edu/pub/treebank/public_html/tokenization.html), and we need to prevent spaCy from using its own tokenizer on top of this. We therefore override spaCy&rsquo;s tokenizer with one that simply splits on space.

# %%
from spacy.tokens import Doc

class WhitespaceTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        return Doc(self.vocab, words=text.split(" "))

nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)

# %% [markdown]
# ## Data set

# %% [markdown]
# The main data set for this lab is a collection of news wire articles in which mentions of named entities have been annotated with page names from the [English Wikipedia](https://en.wikipedia.org/wiki/). The next code cell loads the training and the development parts of the data into Pandas data frames.

# %%
import bz2
import csv
import pandas as pd

with bz2.open("ner-train.tsv.bz2", 'rt') as source:
    df_train = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

with bz2.open("ner-dev.tsv.bz2", 'rt') as source:
    df_dev = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# Each row in these two data frames corresponds to one mention of a named entity and has five columns:
#
# 1. a unique identifier for the sentence containing the entity mention
# 2. the pre-tokenized sentence, with tokens separated by spaces
# 3. the start position of the token span containing the entity mention
# 4. the end position of the token span (exclusive, as in Python list indexing)
# 5. the entity label; either a Wikipedia page name or the generic label `--NME--`
#
# The following cell prints the first five samples from the training data:

# %%
df_train.head()
# Out:
#   sentence_id                                          sentence  beg  end  \
# 0    0000-000  EU rejects German call to boycott British lamb .    0    1
# 1    0000-000  EU rejects German call to boycott British lamb .    2    3
# 2    0000-000  EU rejects German call to boycott British lamb .    6    7
# 3    0000-001                                   Peter Blackburn    0    2
# 4    0000-002                               BRUSSELS 1996-08-22    0    1
#
#             label
# 0         --NME--
# 1         Germany
# 2  United_Kingdom
# 3         --NME--
# 4        Brussels

# %% [markdown]
# In this sample, we see that the first sentence is annotated with three entity mentions:
#
# * the span 0–1 &lsquo;EU&rsquo; is annotated as a mention but only labelled with the generic `--NME--`
# * the span 2–3 &lsquo;German&rsquo; is annotated with the page [Germany](http://en.wikipedia.org/wiki/Germany)
# * the span 6–7 &lsquo;British&rsquo; is annotated with the page [United_Kingdom](http://en.wikipedia.org/wiki/United_Kingdom)

# %% [markdown]
# ## Problem 1: Evaluation measures

# %% [markdown]
# To warm up, we ask you to write code to print the three measures that you will be using for evaluation:

# %%
import numpy as np

def evaluation_report(gold, pred):
    """Print precision, recall, and F1 score.
    
    Args:
        gold: The set with the gold-standard values.
        pred: The set with the predicted values.
    
    Returns:
        Nothing, but prints the precision, recall, and F1 values computed
        based on the specified sets.
    """
    # TODO: Replace the next line with your own code
    
    intersection = gold.intersection(pred)
    precision = len(intersection)/len(pred)
    recall = len(intersection)/len(gold)
    f1 = (2*(precision*recall))/(precision+recall)
    print("Precision :{:.0%}, Recall :{:.0%},F1-value :{:.0%}".format(precision,recall,f1))

# %% [markdown]
# To test your code, you can run the following cell:

# %%
evaluation_report(set(range(3)), set(range(5)))
# Out:
# Precision :60%, Recall :100%,F1-value :75%

# %% [markdown]
# This should give you a precision of 60%, a recall of 100%, and an F1-value of 75%.

# %% [markdown]
# ## Problem 2: Span recognition

# %% [markdown]
# One of the first tasks that an information extraction system has to solve is to locate and classify (mentions of) named entities, such as persons and organizations. Here we will tackle the simpler task of recognizing **spans** of tokens that contain an entity mention, without the actual entity label.
#
# The English language model in spaCy features a full-fledged [named entity recognizer](https://spacy.io/usage/linguistic-features#named-entities) that identifies a variety of entities, and can be updated with new entity types by the user. Your task in this problem is to evaluate the performance of this component when predicting entity spans in the development data.
#
# Start by implementing a generator function that yields the gold-standard spans in a given data frame.
#
# **Hint:** The Pandas method [`itertuples()`](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.itertuples.html) is useful when iterating over the rows in a DataFrame.

# %%
def gold_spans(df):
    """Yield the gold-standard mention spans in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        triples consisting of the sentence id, start position, and end
        position of each span.
    """
    # TODO: Replace the next line with your own code
    for row in df.itertuples(index=False):
        #print(row[1])
        yield row.sentence_id,row.beg,row.end

# %% [markdown]
# To test your code, you can count the spans yielded by your function. When called on the development data, you should get a total of 5,917 unique triples. The first triple and the last triple should be
#
#     ('0946-000', 2, 3)
#     ('1161-010', 1, 3)

# %%
spans_dev_gold = set(gold_spans(df_dev))
print(len(spans_dev_gold))
# Out:
# 5917

# %%
for i,item in enumerate(spans_dev_gold):
    if i==0 or i==(len(spans_dev_gold)-1):
        print(item,i)
# Out:
# ('1116-025', 4, 6) 0
# ('1116-037', 17, 18) 5916

# %%
# TODO: Write code here to run and evaluate the spaCy NER on the development data
# def predict_entities(df):
#     visited = []
#     for row in df_dev.itertuples():
#         if row.sentence_id not in visited:
#             doc = nlp(row.sentence)
#             for ent in doc.ents:
#                 yield (ent.label_)
#         visited.append(row.sentence_id)

# %%
df_dev.head(n=10)
# Out:
#   sentence_id                                           sentence  beg  end  \
# 0    0946-000  CRICKET - LEICESTERSHIRE TAKE OVER AT TOP AFTE...    2    3
# 1    0946-001                                  LONDON 1996-08-30    0    1
# 2    0946-002  West Indian all-rounder Phil Simmons took four...    0    2
# 3    0946-002  West Indian all-rounder Phil Simmons took four...    3    5
# 4    0946-002  West Indian all-rounder Phil Simmons took four...   12   13
# 5    0946-002  West Indian all-rounder Phil Simmons took four...   14   15
# 6    0946-003  Their stay on top , though , may be short-live...   13   14
# 7    0946-003  Their stay on top , though , may be short-live...   15   16
# 8    0946-003  Their stay on top , though , may be short-live...   17   18
# 9    0946-003  Their stay on top , though , may be short-live...   24   25
#
#                                 label
# 0  Leicestershire_County_Cricket_Club
# 1                              London
# 2            West_Indies_cricket_team
# 3                        Phil_Simmons
# 4  Leicestershire_County_Cricket_Club
# 5        Somerset_County_Cricket_Club
# 6           Essex_County_Cricket_Club
# 7      Derbyshire_County_Cricket_Club
# 8          Surrey_County_Cricket_Club
# 9            Kent_County_Cricket_Club

# %% [markdown]
# Your next task is to write code that calls spaCy to predict the named entities in the development data, and to evaluate the accuracy of these predictions in terms of precision, recall, and F1. Print these scores using the function that you wrote for Problem&nbsp;1.

# %%
def foo(df):
        for indx in df.sentence_id.unique():
            sentence = df.loc[df.sentence_id==indx,'sentence']
            doc = nlp(sentence.values[0])
            for ent in doc.ents:
                yield indx,ent.start,ent.end
                
predictions = set(foo(df_dev)) # ;predictions

# %%
evaluation_report(spans_dev_gold,predictions)
# Out:
# Precision :53%, Recall :69%,F1-value :60%

# %%
# !echo houston we have a problem
# Out:
# houston we have a problem

# %% [markdown]
# ## Problem 3: Error analysis

# %% [markdown]
# As you were able to see in Problem&nbsp;2, the span accuracy of the named entity recognizer is far from perfect. In particular, only slightly more than half of the predicted spans are correct according to the gold standard. Your next task is to analyse this result in more detail.
#
# Write code that prints the false positives and the false negatives from the automatic prediction. Have a look at the output. What are your observations? How could you improve the result? Discuss these questions in a short text.

# %%
# TODO: Write code here to do your analysis

# %% [markdown]
# *TODO: Write a short text that discusses the errors that you observed*

# %% [markdown]
# Now, use the insights from your error analysis to improve the automated prediction that you implemented in Problem&nbsp;2. While the best way to do this would be to [update spaCy&rsquo;s NER model](https://spacy.io/usage/linguistic-features#updating) using domain-specific training data, for this lab it suffices to write code to pre-process the data and/or post-process the output produced by spaCy. You should be able to improve the F1 score from Problem&nbsp;2 by at last 15 percentage points.

# %%
# TODO: Write code here to improve the span prediction from Problem 2
def foo2(df):
        for indx in df.sentence_id.unique():
            sentence = df.loc[df.sentence_id==indx,'sentence']
            doc = nlp(sentence.values[0])
            for ent in doc.ents:
                if ent.label_ not in ['CARDINAL', 'ORDINAL', 'QUANTITY', 'MONEY', 'PERCENT', 'TIME', 'DATE']:
                    yield indx,ent.start,ent.end


new_preds = set(foo2(df_dev)) # ;new_preds

# %%
evaluation_report(spans_dev_gold,new_preds)
# Out:
# Precision :84%, Recall :69%,F1-value :76%

# %% [markdown]
# Show that you achieve the performance goal by reporting the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# Before going on, we ask you to store the outputs of the improved named entity recognizer on the development data in a new data frame. This new frame should have the same layout as the original data frame for the development data that you loaded above, but should contain the predicted start and end positions for each token span. As the `label` of each span, you can use the special value `--NME--`.

# %%
# TODO: Write code here to store the predicted spans in a new data frame
preds_list = list(new_preds) #;preds_list

x=[item[0] for item in preds_list]
y=[item[1] for item in preds_list]
z=[item[2] for item in preds_list]

# create a list with the indexes for each predicted span
indexes_list = []
for i in range(len(x)):
    indexes_list.append(df_dev.index[(df_dev['sentence_id']==x[i]) & (df_dev['beg']==y[i]) & (df_dev['end']==z[i])].tolist())

# %%
#len(indexes_list)

# %%
from functools import reduce
# flatten the indexes list 
flat_list = reduce(lambda x, y: x+y, indexes_list)

# %%
# create the dataframe

df_dev_small = df_dev.iloc[flat_list,:]
df_dev_small.drop(['label'],axis=1)
df_dev_small.label='--NME--'
df_dev_small.head(n=10)
# Out:
#      sentence_id                                           sentence  beg  end  \
# 3426    1065-017                           Livingston 3 3 0 0 6 2 9    0    1
# 5521    1143-005  on August 29 , " an Israeli army spokeswoman s...    6    7
# 369     0957-020  Add Men 's singles , second round 1 - Pete Sam...   29   30
# 1435    0990-006  Lebed , whom Yeltsin ordered to restore peace ...    0    1
# 2313    1027-015  It is our duty towards al-Aqsa to come and pra...    5    6
# 5431    1139-008  Wang was jailed for two years for organising s...   20   21
# 828     0966-082                  2. Samuel Matete ( Zambia ) 48.34    1    3
# 2421    1031-012  China 's second largest telecoms operator Unic...    0    1
# 5676    1152-010  The U.S. defense officials said military fligh...    1    2
# 1863    1008-023  In an interview on the cable television networ...   14   16
#
#         label
# 3426  --NME--
# 5521  --NME--
# 369   --NME--
# 1435  --NME--
# 2313  --NME--
# 5431  --NME--
# 828   --NME--
# 2421  --NME--
# 5676  --NME--
# 1863  --NME--

# %% [markdown]
# ## Problem 4: Entity linking

# %% [markdown]
# Now that we have a method for predicting mention spans, we turn to the task of **entity linking**, which amounts to predicting the knowledge base entity that is referenced by a given mention. In our case, for each span we want to predict the Wikipedia page that this mention references.
#
# Start by extending the generator function that you implemented in Problem&nbsp;2 to labelled spans.

# %%
def gold_mentions(df):
    """Yield the gold-standard mentions in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        quadruples consisting of the sentence id, start position, end
        position and entity label of each span.
    """
    # TODO: Replace the next line with your own code
    for row in df.itertuples():
        yield row.sentence_id,row.beg,row.end,row.label

# %% [markdown]
# A naive baseline for entity linking on our data set is to link each mention span to the Wikipedia page name that we get when we join the tokens in the span by underscores, as is standard in Wikipedia page names. Suppose, for example, that a span contains the two tokens
#
#     Jimi Hendrix
#
# The baseline Wikipedia page name for this span would be
#
#     Jimi_Hendrix
#
# Implement this naive baseline and evaluate its performance. Print the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# <div class="alert alert-warning">
#     Here and in the remainder of this lab, you should base your entity predictions on the predicted spans that you computed in Problem&nbsp;3.
# </div>

# %%
# TODO: Write code here to implement the baseline

def foojin(df):
    for indx in df.sentence_id.unique():
            sentence = df.loc[df.sentence_id==indx,'sentence']
            sentence_list = sentence.values[0].split()
            start = df.loc[df.sentence_id==indx,'beg'].values[0]
            end = df.loc[df.sentence_id==indx,'end'].values[0]
            words = sentence_list[start : end]
            join_sentence = "_".join(words)
            doc = nlp(join_sentence)
            for ent in doc.ents:
                yield indx,start,end,ent.label_
    
    
x = set(foojin(df_dev_small))

# %%
x
# Out:
# {('0946-001', 0, 1, 'GPE'),
#  ('0946-003', 17, 18, 'ORG'),
#  ('0946-007', 5, 6, 'GPE'),
#  ('0946-010', 13, 14, 'ORG'),
#  ('0947-001', 0, 1, 'GPE'),
#  ('0947-008', 0, 1, 'GPE'),
#  ('0948-001', 0, 1, 'GPE'),
#  ('0948-002', 0, 1, 'GPE'),
#  ('0948-003', 4, 5, 'GPE'),
#  ('0948-006', 0, 1, 'GPE'),
#  ('0948-011', 0, 1, 'GPE'),
#  ('0948-014', 4, 5, 'GPE'),
#  ('0948-017', 3, 4, 'ORG'),
#  ('0948-019', 3, 4, 'PERSON'),
#  ('0948-023', 0, 1, 'GPE'),
#  ('0948-024', 10, 11, 'GPE'),
#  ('0948-025', 7, 8, 'ORG'),
#  ('0948-029', 9, 10, 'GPE'),
#  ('0948-038', 3, 4, 'GPE'),
#  ('0948-046', 9, 10, 'GPE'),
#  ('0949-001', 0, 1, 'GPE'),
#  ('0949-002', 12, 13, 'GPE'),
#  ('0949-010', 2, 4, 'ORG'),
#  ('0949-011', 8, 9, 'GPE'),
#  ('0951-002', 0, 1, 'GPE'),
#  ('0952-003', 4, 5, 'NORP'),
#  ('0953-002', 0, 1, 'NORP'),
#  ('0953-003', 7, 8, 'NORP'),
#  ('0953-008', 8, 9, 'ORG'),
#  ('0953-013', 8, 9, 'NORP'),
#  ('0954-003', 9, 10, 'GPE'),
#  ('0954-004', 5, 6, 'GPE'),
#  ('0956-005', 2, 3, 'ORG'),
#  ('0956-006', 0, 1, 'ORG'),
#  ('0956-017', 0, 1, 'ORG'),
#  ('0957-006', 11, 12, 'GPE'),
#  ('0957-008', 3, 4, 'GPE'),
#  ('0957-013', 3, 4, 'GPE'),
#  ('0957-015', 5, 6, 'GPE'),
#  ('0957-024', 0, 2, 'PERSON'),
#  ('0958-015', 0, 1, 'ORG'),
#  ('0958-019', 0, 1, 'ORG'),
#  ('0958-022', 0, 1, 'GPE'),
#  ('0958-026', 0, 1, 'ORG'),
#  ('0958-027', 2, 3, 'ORG'),
#  ('0958-028', 3, 4, 'GPE'),
#  ('0958-033', 0, 1, 'ORG'),
#  ('0958-035', 0, 1, 'GPE'),
#  ('0958-051', 0, 1, 'GPE'),
#  ('0959-006', 0, 1, 'GPE'),
#  ('0959-007', 0, 1, 'GPE'),
#  ('0959-011', 0, 1, 'GPE'),
#  ('0959-012', 0, 1, 'GPE'),
#  ('0959-013', 0, 1, 'GPE'),
#  ('0959-015', 0, 1, 'GPE'),
#  ('0960-003', 9, 11, 'CARDINAL'),
#  ('0960-004', 8, 9, 'ORG'),
#  ('0960-013', 6, 7, 'GPE'),
#  ('0960-014', 12, 13, 'GPE'),
#  ('0960-015', 21, 22, 'GPE'),
#  ('0960-017', 15, 16, 'GPE'),
#  ('0960-019', 3, 4, 'ORG'),
#  ('0960-020', 12, 13, 'NORP'),
#  ('0960-023', 10, 11, 'NORP'),
#  ('0960-037', 3, 4, 'NORP'),
#  ('0961-003', 0, 1, 'ORG'),
#  ('0961-004', 6, 7, 'ORG'),
#  ('0961-005', 14, 15, 'GPE'),
#  ('0961-007', 10, 11, 'ORG'),
#  ('0961-009', 6, 7, 'ORG'),
#  ('0961-010', 0, 1, 'ORG'),
#  ('0962-001', 2, 3, 'GPE'),
#  ('0962-005', 4, 5, 'GPE'),
#  ('0963-001', 2, 3, 'GPE'),
#  ('0964-000', 11, 12, 'ORG'),
#  ('0964-002', 0, 1, 'NORP'),
#  ('0964-003', 5, 6, 'GPE'),
#  ('0965-004', 16, 17, 'ORG'),
#  ('0965-007', 25, 26, 'GPE'),
#  ('0965-009', 2, 3, 'GPE'),
#  ('0965-011', 31, 32, 'GPE'),
#  ('0965-012', 13, 14, 'ORG'),
#  ('0966-006', 4, 5, 'GPE'),
#  ('0966-008', 4, 5, 'GPE'),
#  ('0966-010', 4, 5, 'GPE'),
#  ('0966-012', 4, 5, 'GPE'),
#  ('0966-013', 4, 5, 'GPE'),
#  ('0966-015', 4, 5, 'GPE'),
#  ('0966-016', 4, 5, 'GPE'),
#  ('0966-018', 4, 5, 'GPE'),
#  ('0966-019', 4, 5, 'GPE'),
#  ('0966-021', 4, 5, 'GPE'),
#  ('0966-022', 4, 5, 'GPE'),
#  ('0966-023', 4, 5, 'GPE'),
#  ('0966-024', 4, 5, 'GPE'),
#  ('0966-025', 4, 5, 'GPE'),
#  ('0966-026', 4, 5, 'GPE'),
#  ('0966-027', 4, 5, 'GPE'),
#  ('0966-028', 4, 5, 'GPE'),
#  ('0966-031', 4, 5, 'GPE'),
#  ('0966-032', 4, 5, 'GPE'),
#  ('0966-033', 4, 5, 'GPE'),
#  ('0966-035', 4, 5, 'GPE'),
#  ('0966-040', 4, 5, 'GPE'),
#  ('0966-041', 4, 5, 'GPE'),
#  ('0966-042', 4, 5, 'GPE'),
#  ('0966-045', 4, 5, 'GPE'),
#  ('0966-047', 4, 5, 'GPE'),
#  ('0966-048', 4, 5, 'GPE'),
#  ('0966-050', 1, 3, 'ORG'),
#  ('0966-051', 4, 5, 'GPE'),
#  ('0966-052', 4, 5, 'GPE'),
#  ('0966-055', 4, 5, 'GPE'),
#  ('0966-058', 4, 5, 'GPE'),
#  ('0966-060', 4, 5, 'GPE'),
#  ('0966-061', 4, 5, 'GPE'),
#  ('0966-064', 4, 5, 'GPE'),
#  ('0966-065', 4, 5, 'GPE'),
#  ('0966-067', 4, 5, 'GPE'),
#  ('0966-069', 4, 5, 'GPE'),
#  ('0966-070', 4, 5, 'GPE'),
#  ('0966-072', 4, 5, 'GPE'),
#  ('0966-073', 4, 5, 'GPE'),
#  ('0966-075', 4, 5, 'GPE'),
#  ('0966-076', 4, 5, 'GPE'),
#  ('0966-078', 4, 5, 'GPE'),
#  ('0966-079', 4, 5, 'GPE'),
#  ('0966-081', 4, 5, 'GPE'),
#  ('0966-083', 4, 5, 'GPE'),
#  ('0966-084', 4, 5, 'GPE'),
#  ('0966-085', 4, 5, 'GPE'),
#  ('0966-086', 4, 5, 'GPE'),
#  ('0966-093', 4, 5, 'GPE'),
#  ('0966-095', 4, 5, 'GPE'),
#  ('0966-096', 4, 5, 'GPE'),
#  ('0966-099', 4, 5, 'GPE'),
#  ('0966-101', 4, 5, 'GPE'),
#  ('0966-102', 4, 5, 'GPE'),
#  ('0966-104', 4, 5, 'GPE'),
#  ('0966-105', 4, 5, 'GPE'),
#  ('0966-109', 4, 5, 'GPE'),
#  ('0966-110', 4, 5, 'GPE'),
#  ('0966-111', 4, 5, 'GPE'),
#  ('0966-113', 4, 5, 'GPE'),
#  ('0966-114', 4, 5, 'GPE'),
#  ('0966-116', 4, 5, 'GPE'),
#  ('0966-117', 4, 5, 'GPE'),
#  ('0966-119', 4, 5, 'GPE'),
#  ('0966-121', 4, 5, 'GPE'),
#  ('0966-127', 4, 5, 'GPE'),
#  ('0966-128', 4, 5, 'GPE'),
#  ('0966-129', 4, 5, 'GPE'),
#  ('0966-130', 4, 5, 'GPE'),
#  ('0966-131', 4, 5, 'GPE'),
#  ('0966-132', 4, 5, 'GPE'),
#  ('0966-135', 4, 5, 'GPE'),
#  ('0966-136', 4, 5, 'GPE'),
#  ('0966-137', 5, 6, 'GPE'),
#  ('0966-138', 4, 5, 'GPE'),
#  ('0966-139', 4, 5, 'GPE'),
#  ('0966-141', 4, 5, 'GPE'),
#  ('0966-143', 4, 5, 'GPE'),
#  ('0966-146', 4, 5, 'GPE'),
#  ('0966-148', 4, 5, 'GPE'),
#  ('0966-149', 4, 5, 'GPE'),
#  ('0966-150', 4, 5, 'GPE'),
#  ('0966-152', 1, 3, 'ORG'),
#  ('0966-153', 4, 5, 'GPE'),
#  ('0966-155', 4, 5, 'GPE'),
#  ('0966-156', 4, 5, 'GPE'),
#  ('0966-157', 4, 5, 'GPE'),
#  ('0966-159', 4, 5, 'GPE'),
#  ('0966-164', 16, 17, 'GPE'),
#  ('0969-001', 2, 3, 'GPE'),
#  ('0970-005', 28, 29, 'ORG'),
#  ('0972-004', 0, 1, 'GPE'),
#  ('0972-011', 0, 2, 'CARDINAL'),
#  ('0972-020', 9, 10, 'GPE'),
#  ('0972-028', 0, 2, 'ORG'),
#  ('0972-037', 3, 4, 'ORG'),
#  ('0972-040', 6, 7, 'GPE'),
#  ('0973-002', 0, 1, 'GPE'),
#  ('0974-002', 0, 1, 'GPE'),
#  ('0977-000', 0, 1, 'GPE'),
#  ('0977-002', 3, 4, 'GPE'),
#  ('0977-007', 0, 1, 'ORG'),
#  ('0977-008', 0, 1, 'GPE'),
#  ('0977-012', 0, 1, 'NORP'),
#  ('0977-013', 1, 2, 'NORP'),
#  ('0978-002', 15, 17, 'GPE'),
#  ('0978-005', 1, 2, 'GPE'),
#  ('0979-003', 17, 18, 'GPE'),
#  ('0980-000', 0, 1, 'GPE'),
#  ('0980-002', 36, 37, 'GPE'),
#  ('0980-003', 3, 4, 'ORG'),
#  ('0980-006', 1, 2, 'GPE'),
#  ('0980-013', 7, 8, 'GPE'),
#  ('0980-016', 24, 25, 'GPE'),
#  ('0980-017', 2, 3, 'ORG'),
#  ('0981-006', 5, 6, 'ORG'),
#  ('0981-013', 0, 1, 'ORG'),
#  ('0982-000', 0, 1, 'GPE'),
#  ('0982-001', 0, 1, 'GPE'),
#  ('0982-002', 21, 22, 'GPE'),
#  ('0983-000', 0, 1, 'NORP'),
#  ('0983-001', 0, 1, 'GPE'),
#  ('0983-002', 5, 6, 'NORP'),
#  ('0983-004', 1, 2, 'NORP'),
#  ('0983-005', 37, 38, 'GPE'),
#  ('0983-007', 18, 19, 'GPE'),
#  ('0984-001', 0, 1, 'GPE'),
#  ('0984-002', 11, 12, 'NORP'),
#  ('0984-003', 16, 17, 'GPE'),
#  ('0984-008', 15, 16, 'GPE'),
#  ('0984-009', 9, 10, 'GPE'),
#  ('0984-013', 2, 3, 'ORG'),
#  ('0984-016', 18, 19, 'GPE'),
#  ('0984-017', 25, 26, 'GPE'),
#  ('0984-018', 12, 13, 'NORP'),
#  ('0984-019', 14, 15, 'NORP'),
#  ('0985-001', 0, 1, 'GPE'),
#  ('0985-002', 14, 15, 'GPE'),
#  ('0985-006', 6, 7, 'GPE'),
#  ('0985-009', 13, 14, 'NORP'),
#  ('0985-010', 5, 6, 'ORG'),
#  ('0985-012', 20, 21, 'ORG'),
#  ('0986-003', 0, 1, 'GPE'),
#  ('0987-000', 0, 1, 'NORP'),
#  ('0988-006', 1, 2, 'GPE'),
#  ('0990-007', 28, 29, 'GPE'),
#  ('0990-009', 6, 7, 'GPE'),
#  ('0990-011', 18, 19, 'GPE'),
#  ('0991-002', 22, 23, 'GPE'),
#  ('0991-008', 21, 22, 'GPE'),
#  ('0991-009', 10, 11, 'GPE'),
#  ('0991-010', 9, 10, 'GPE'),
#  ('0992-000', 1, 2, 'ORG'),
#  ('0992-002', 0, 1, 'GPE'),
#  ('0992-004', 14, 15, 'GPE'),
#  ('0992-006', 6, 7, 'GPE'),
#  ('0992-007', 29, 30, 'NORP'),
#  ('0992-008', 9, 10, 'ORG'),
#  ('0992-009', 13, 14, 'ORG'),
#  ('0993-000', 0, 1, 'GPE'),
#  ('0993-002', 0, 1, 'GPE'),
#  ('0993-007', 4, 5, 'GPE'),
#  ('0994-005', 18, 19, 'NORP'),
#  ('0994-010', 23, 24, 'GPE'),
#  ('0994-014', 0, 1, 'ORG'),
#  ('0994-015', 10, 11, 'GPE'),
#  ('0994-016', 0, 1, 'ORG'),
#  ('0995-003', 11, 12, 'GPE'),
#  ('0995-005', 5, 6, 'GPE'),
#  ('0995-007', 0, 1, 'GPE'),
#  ('0995-012', 0, 1, 'GPE'),
#  ('0995-019', 20, 21, 'GPE'),
#  ('0996-000', 0, 1, 'NORP'),
#  ('0996-002', 8, 9, 'GPE'),
#  ('0996-004', 12, 13, 'GPE'),
#  ('0996-006', 15, 16, 'GPE'),
#  ('0996-007', 0, 1, 'GPE'),
#  ('0996-008', 0, 1, 'GPE'),
#  ('0997-004', 14, 15, 'NORP'),
#  ('0997-008', 17, 18, 'GPE'),
#  ('0997-009', 23, 24, 'GPE'),
#  ('0998-003', 5, 6, 'GPE'),
#  ('0999-000', 0, 1, 'NORP'),
#  ('0999-002', 1, 2, 'GPE'),
#  ('0999-003', 31, 32, 'GPE'),
#  ('1000-005', 11, 12, 'GPE'),
#  ('1000-014', 6, 7, 'GPE'),
#  ('1000-016', 5, 7, 'ORG'),
#  ('1001-000', 0, 1, 'GPE'),
#  ('1002-000', 4, 5, 'NORP'),
#  ('1002-001', 2, 3, 'GPE'),
#  ('1002-002', 24, 25, 'GPE'),
#  ('1002-003', 14, 15, 'ORG'),
#  ('1003-004', 0, 1, 'GPE'),
#  ('1003-005', 5, 6, 'GPE'),
#  ('1003-007', 0, 1, 'GPE'),
#  ('1004-000', 0, 1, 'NORP'),
#  ('1004-002', 0, 1, 'GPE'),
#  ('1004-003', 22, 23, 'NORP'),
#  ('1004-004', 10, 13, 'ORG'),
#  ('1004-007', 11, 12, 'ORG'),
#  ('1005-005', 18, 19, 'GPE'),
#  ('1005-006', 0, 1, 'GPE'),
#  ('1005-008', 12, 13, 'NORP'),
#  ('1005-009', 5, 6, 'NORP'),
#  ('1006-000', 0, 1, 'GPE'),
#  ('1006-003', 0, 1, 'NORP'),
#  ('1006-005', 21, 22, 'GPE'),
#  ('1006-007', 9, 10, 'GPE'),
#  ('1006-010', 2, 3, 'NORP'),
#  ('1006-011', 6, 7, 'PERSON'),
#  ('1006-013', 16, 17, 'PERSON'),
#  ('1006-014', 0, 1, 'PERSON'),
#  ('1007-011', 0, 1, 'ORG'),
#  ('1007-012', 0, 1, 'ORG'),
#  ('1007-013', 34, 35, 'GPE'),
#  ('1007-016', 19, 20, 'NORP'),
#  ('1007-017', 11, 12, 'ORG'),
#  ('1007-018', 19, 20, 'ORG'),
#  ('1007-019', 0, 1, 'PERSON'),
#  ('1007-024', 18, 19, 'ORG'),
#  ('1008-002', 0, 1, 'GPE'),
#  ('1008-006', 4, 5, 'GPE'),
#  ('1008-011', 9, 10, 'ORG'),
#  ('1008-012', 2, 3, 'ORG'),
#  ('1008-018', 8, 9, 'GPE'),
#  ('1008-029', 50, 51, 'ORG'),
#  ('1009-000', 5, 6, 'GPE'),
#  ('1009-002', 0, 1, 'GPE'),
#  ('1009-003', 7, 8, 'NORP'),
#  ('1009-004', 6, 7, 'NORP'),
#  ('1009-007', 16, 17, 'NORP'),
#  ('1009-008', 10, 11, 'NORP'),
#  ('1009-009', 18, 19, 'GPE'),
#  ('1009-010', 26, 27, 'NORP'),
#  ('1009-011', 0, 1, 'NORP'),
#  ('1009-012', 9, 10, 'GPE'),
#  ('1009-013', 16, 17, 'GPE'),
#  ('1009-014', 14, 15, 'NORP'),
#  ('1009-015', 35, 36, 'GPE'),
#  ('1009-017', 1, 2, 'GPE'),
#  ('1010-000', 0, 1, 'GPE'),
#  ('1010-002', 0, 1, 'GPE'),
#  ('1010-006', 4, 5, 'GPE'),
#  ('1010-016', 7, 8, 'NORP'),
#  ('1010-020', 17, 18, 'GPE'),
#  ('1011-006', 26, 27, 'GPE'),
#  ('1011-009', 0, 4, 'CARDINAL'),
#  ('1011-014', 0, 1, 'ORG'),
#  ('1011-016', 6, 7, 'GPE'),
#  ('1011-017', 7, 8, 'GPE'),
#  ('1011-018', 3, 4, 'GPE'),
#  ('1011-019', 1, 2, 'ORG'),
#  ('1011-022', 4, 5, 'ORG'),
#  ('1011-023', 16, 17, 'ORG'),
#  ('1012-000', 0, 1, 'GPE'),
#  ('1012-001', 0, 1, 'GPE'),
#  ('1012-002', 20, 21, 'GPE'),
#  ('1012-005', 15, 16, 'GPE'),
#  ('1012-006', 22, 23, 'NORP'),
#  ('1012-007', 15, 16, 'GPE'),
#  ('1012-008', 4, 5, 'GPE'),
#  ('1012-009', 10, 11, 'GPE'),
#  ('1014-001', 2, 3, 'GPE'),
#  ('1014-002', 8, 9, 'NORP'),
#  ('1014-008', 1, 3, 'GPE'),
#  ('1014-010', 8, 9, 'GPE'),
#  ('1016-000', 0, 1, 'GPE'),
#  ('1016-002', 1, 2, 'NORP'),
#  ('1016-003', 7, 8, 'NORP'),
#  ('1016-007', 5, 6, 'NORP'),
#  ('1016-008', 44, 45, 'GPE'),
#  ('1016-010', 17, 18, 'NORP'),
#  ('1016-011', 5, 6, 'ORG'),
#  ('1016-012', 13, 14, 'PERSON'),
#  ('1016-013', 14, 15, 'GPE'),
#  ('1017-002', 5, 6, 'NORP'),
#  ('1017-004', 5, 6, 'NORP'),
#  ('1017-006', 23, 24, 'GPE'),
#  ('1018-000', 0, 1, 'NORP'),
#  ('1018-002', 0, 1, 'NORP'),
#  ('1018-006', 20, 21, 'ORG'),
#  ('1019-000', 6, 7, 'NORP'),
#  ('1019-003', 15, 16, 'NORP'),
#  ('1019-004', 17, 18, 'NORP'),
#  ('1019-009', 0, 1, 'NORP'),
#  ('1019-012', 15, 16, 'NORP'),
#  ('1019-013', 8, 9, 'NORP'),
#  ('1020-000', 0, 1, 'NORP'),
#  ('1020-002', 0, 1, 'NORP'),
#  ('1022-000', 0, 1, 'NORP'),
#  ('1022-002', 12, 13, 'GPE'),
#  ('1022-004', 0, 1, 'GPE'),
#  ('1022-005', 1, 2, 'GPE'),
#  ('1022-007', 5, 6, 'GPE'),
#  ('1022-009', 4, 5, 'GPE'),
#  ('1022-010', 20, 21, 'GPE'),
#  ('1022-012', 18, 19, 'NORP'),
#  ('1022-013', 10, 11, 'NORP'),
#  ('1022-015', 1, 2, 'GPE'),
#  ('1022-017', 10, 11, 'GPE'),
#  ('1024-001', 0, 1, 'GPE'),
#  ('1025-000', 2, 3, 'GPE'),
#  ('1025-002', 0, 1, 'GPE'),
#  ('1025-003', 4, 5, 'NORP'),
#  ('1025-006', 6, 7, 'GPE'),
#  ('1025-007', 3, 4, 'NORP'),
#  ('1025-008', 15, 16, 'NORP'),
#  ('1025-009', 6, 7, 'GPE'),
#  ('1025-010', 13, 14, 'GPE'),
#  ('1025-011', 30, 31, 'GPE'),
#  ('1025-012', 7, 8, 'GPE'),
#  ('1026-000', 5, 6, 'ORG'),
#  ('1026-002', 7, 8, 'GPE'),
#  ('1027-000', 0, 1, 'GPE'),
#  ('1027-004', 1, 2, 'NORP'),
#  ('1027-006', 8, 9, 'NORP'),
#  ('1027-007', 21, 22, 'NORP'),
#  ('1027-009', 0, 1, 'NORP'),
#  ('1027-010', 1, 2, 'NORP'),
#  ('1027-011', 1, 2, 'ORG'),
#  ('1027-012', 3, 4, 'NORP'),
#  ('1027-014', 8, 9, 'PERSON'),
#  ('1027-016', 19, 20, 'GPE'),
#  ('1027-019', 5, 6, 'GPE'),
#  ('1027-020', 12, 13, 'NORP'),
#  ('1027-021', 2, 3, 'NORP'),
#  ('1027-025', 8, 9, 'NORP'),
#  ('1028-013', 7, 8, 'GPE'),
#  ('1029-002', 0, 1, 'GPE'),
#  ('1029-013', 17, 18, 'GPE'),
#  ('1030-004', 3, 4, 'GPE'),
#  ('1030-013', 6, 7, 'NORP'),
#  ('1030-016', 7, 8, 'ORG'),
#  ('1030-026', 3, 4, 'ORG'),
#  ('1030-030', 13, 14, 'ORG'),
#  ('1030-031', 8, 9, 'ORG'),
#  ('1030-032', 15, 16, 'NORP'),
#  ('1030-036', 19, 20, 'GPE'),
#  ('1030-038', 29, 30, 'GPE'),
#  ('1030-039', 2, 3, 'GPE'),
#  ('1030-040', 1, 2, 'GPE'),
#  ('1031-000', 5, 6, 'NORP'),
#  ('1031-003', 25, 26, 'NORP'),
#  ('1031-007', 29, 30, 'NORP'),
#  ('1031-010', 14, 15, 'GPE'),
#  ('1031-011', 10, 11, 'NORP'),
#  ('1031-012', 0, 1, 'GPE'),
#  ('1031-014', 30, 31, 'LOC'),
#  ('1031-016', 9, 10, 'GPE'),
#  ('1032-000', 0, 1, 'NORP'),
#  ('1032-002', 7, 8, 'NORP'),
#  ('1033-000', 0, 1, 'ORG'),
#  ('1033-002', 22, 23, 'GPE'),
#  ('1033-003', 15, 16, 'ORG'),
#  ('1033-004', 2, 3, 'ORG'),
#  ('1033-005', 7, 8, 'ORG'),
#  ('1033-006', 3, 4, 'GPE'),
#  ('1033-009', 7, 8, 'GPE'),
#  ('1033-010', 30, 31, 'ORG'),
#  ('1033-011', 16, 17, 'GPE'),
#  ('1034-002', 1, 2, 'NORP'),
#  ('1034-004', 13, 14, 'NORP'),
#  ('1035-002', 11, 12, 'GPE'),
#  ('1035-007', 18, 19, 'GPE'),
#  ('1036-002', 2, 3, 'GPE'),
#  ('1036-005', 6, 7, 'NORP'),
#  ('1036-011', 22, 23, 'ORG'),
#  ('1036-013', 4, 5, 'NORP'),
#  ('1036-014', 3, 4, 'NORP'),
#  ('1036-018', 16, 17, 'NORP'),
#  ('1036-020', 8, 9, 'NORP'),
#  ('1036-026', 6, 7, 'GPE'),
#  ('1036-031', 0, 1, 'ORG'),
#  ('1036-034', 0, 1, 'GPE'),
#  ('1036-035', 1, 2, 'GPE'),
#  ('1037-002', 28, 29, 'GPE'),
#  ('1038-002', 26, 27, 'NORP'),
#  ('1038-004', 28, 29, 'GPE'),
#  ('1038-005', 37, 38, 'ORG'),
#  ('1038-008', 1, 2, 'GPE'),
#  ('1039-001', 6, 7, 'NORP'),
#  ('1039-002', 0, 1, 'ORG'),
#  ('1039-007', 0, 1, 'NORP'),
#  ('1039-011', 20, 21, 'NORP'),
#  ('1039-014', 19, 20, 'GPE'),
#  ('1039-015', 32, 33, 'GPE'),
#  ('1042-000', 5, 6, 'GPE'),
#  ('1042-002', 3, 4, 'GPE'),
#  ('1042-003', 12, 13, 'GPE'),
#  ('1042-007', 10, 11, 'ORG'),
#  ('1043-000', 2, 3, 'NORP'),
#  ('1043-004', 0, 1, 'GPE'),
#  ('1043-005', 10, 11, 'GPE'),
#  ('1044-000', 0, 1, 'PERSON'),
#  ('1044-003', 3, 4, 'PERSON'),
#  ('1044-004', 11, 12, 'NORP'),
#  ('1044-005', 0, 1, 'NORP'),
#  ('1044-006', 0, 1, 'GPE'),
#  ('1044-007', 9, 10, 'GPE'),
#  ('1045-005', 8, 9, 'NORP'),
#  ('1045-006', 11, 12, 'GPE'),
#  ('1045-007', 21, 22, 'NORP'),
#  ('1045-008', 28, 29, 'NORP'),
#  ('1045-009', 12, 13, 'GPE'),
#  ('1045-010', 0, 1, 'GPE'),
#  ('1046-001', 3, 4, 'GPE'),
#  ('1046-003', 1, 2, 'NORP'),
#  ('1046-008', 14, 15, 'PERSON'),
#  ('1046-010', 21, 22, 'GPE'),
#  ('1048-001', 2, 3, 'GPE'),
#  ('1048-002', 2, 3, 'NORP'),
#  ('1049-003', 27, 28, 'ORG'),
#  ('1049-004', 5, 6, 'GPE'),
#  ('1050-002', 16, 17, 'NORP'),
#  ('1051-002', 15, 16, 'NORP'),
#  ('1051-003', 4, 5, 'GPE'),
#  ('1051-007', 4, 5, 'GPE'),
#  ('1051-008', 14, 15, 'GPE'),
#  ('1051-010', 25, 27, 'ORG'),
#  ('1051-011', 18, 19, 'GPE'),
#  ('1052-002', 15, 16, 'NORP'),
#  ('1053-002', 0, 1, 'GPE'),
#  ('1054-006', 4, 5, 'GPE'),
#  ('1054-012', 4, 5, 'GPE'),
#  ('1054-017', 4, 5, 'GPE'),
#  ('1054-019', 4, 5, 'GPE'),
#  ('1055-002', 8, 9, 'GPE'),
#  ('1055-003', 0, 1, 'GPE'),
#  ('1055-006', 0, 2, 'CARDINAL'),
#  ('1055-024', 0, 2, 'ORG'),
#  ('1056-001', 0, 1, 'ORG'),
#  ('1056-007', 4, 5, 'GPE'),
#  ('1056-008', 4, 5, 'GPE'),
#  ('1056-009', 4, 5, 'GPE'),
#  ('1056-010', 4, 5, 'GPE'),
#  ('1056-011', 4, 5, 'GPE'),
#  ('1056-013', 4, 5, 'GPE'),
#  ('1056-014', 4, 5, 'GPE'),
#  ('1056-016', 20, 21, 'GPE'),
#  ('1056-018', 0, 1, 'GPE'),
#  ('1056-021', 4, 5, 'GPE'),
#  ('1056-022', 4, 5, 'GPE'),
#  ('1056-023', 4, 5, 'GPE'),
#  ('1056-024', 4, 5, 'GPE'),
#  ('1056-026', 4, 5, 'GPE'),
#  ('1056-027', 4, 5, 'GPE'),
#  ('1056-030', 4, 5, 'GPE'),
#  ('1056-031', 1, 3, 'ORG'),
#  ('1056-032', 4, 5, 'GPE'),
#  ('1056-038', 9, 10, 'GPE'),
#  ('1056-039', 3, 4, 'GPE'),
#  ('1056-044', 3, 4, 'GPE'),
#  ('1056-045', 1, 2, 'GPE'),
#  ('1056-046', 3, 4, 'GPE'),
#  ('1057-002', 18, 19, 'ORG'),
#  ('1057-004', 0, 1, 'GPE'),
#  ('1058-003', 16, 17, 'GPE'),
#  ('1058-005', 20, 21, 'GPE'),
#  ('1058-008', 1, 2, 'NORP'),
#  ('1058-009', 15, 16, 'GPE'),
#  ('1058-014', 0, 1, 'GPE'),
#  ('1058-015', 0, 1, 'GPE'),
#  ('1058-019', 5, 6, 'ORG'),
#  ('1058-022', 1, 2, 'GPE'),
#  ('1058-023', 2, 3, 'ORG'),
#  ('1058-025', 12, 13, 'GPE'),
#  ('1058-035', 3, 4, 'GPE'),
#  ('1059-001', 0, 1, 'GPE'),
#  ('1059-002', 20, 21, 'ORG'),
#  ('1060-001', 0, 1, 'GPE'),
#  ('1060-004', 2, 3, 'NORP'),
#  ('1060-007', 4, 5, 'GPE'),
#  ('1060-009', 4, 5, 'GPE'),
#  ('1060-010', 4, 5, 'GPE'),
#  ('1060-012', 4, 5, 'GPE'),
#  ('1060-015', 4, 5, 'GPE'),
#  ('1060-017', 4, 5, 'GPE'),
#  ('1060-018', 4, 5, 'GPE'),
#  ('1060-022', 5, 6, 'GPE'),
#  ('1061-000', 5, 6, 'ORG'),
#  ('1061-001', 0, 1, 'GPE'),
#  ('1061-007', 0, 1, 'ORG'),
#  ('1061-017', 0, 1, 'NORP'),
#  ('1062-002', 14, 15, 'NORP'),
#  ('1063-001', 0, 1, 'GPE'),
#  ('1063-002', 14, 15, 'NORP'),
#  ('1064-001', 0, 1, 'GPE'),
#  ('1064-005', 2, 3, 'NORP'),
#  ('1064-007', 37, 38, 'ORG'),
#  ('1065-001', 0, 1, 'GPE'),
#  ('1065-012', 0, 1, 'ORG'),
#  ('1065-017', 0, 1, 'GPE'),
#  ('1065-022', 0, 1, 'ORG'),
#  ('1065-025', 0, 1, 'ORG'),
#  ('1066-001', 0, 1, 'GPE'),
#  ('1066-007', 0, 1, 'ORG'),
#  ('1066-010', 0, 1, 'PERSON'),
#  ('1066-013', 0, 1, 'ORG'),
#  ('1066-017', 0, 2, 'ORG'),
#  ('1066-019', 0, 1, 'GPE'),
#  ('1066-029', 0, 1, 'ORG'),
#  ('1066-040', 0, 1, 'ORG'),
#  ('1066-044', 0, 1, 'ORG'),
#  ('1066-045', 0, 1, 'ORG'),
#  ('1066-053', 0, 1, 'ORG'),
#  ('1066-065', 0, 1, 'ORG'),
#  ('1066-066', 0, 1, 'ORG'),
#  ('1066-070', 0, 1, 'GPE'),
#  ('1066-079', 0, 1, 'GPE'),
#  ('1067-002', 2, 3, 'NORP'),
#  ('1067-014', 0, 1, 'GPE'),
#  ('1068-001', 0, 1, 'GPE'),
#  ('1068-007', 2, 4, 'ORG'),
#  ('1068-013', 4, 5, 'ORG'),
#  ('1068-020', 0, 1, 'ORG'),
#  ('1068-035', 0, 1, 'GPE'),
#  ('1069-001', 0, 1, 'GPE'),
#  ('1069-012', 4, 5, 'GPE'),
#  ('1069-018', 1, 2, 'ORG'),
#  ('1070-008', 4, 5, 'GPE'),
#  ('1070-012', 7, 9, 'CARDINAL'),
#  ('1070-013', 5, 6, 'GPE'),
#  ('1070-014', 4, 5, 'GPE'),
#  ('1070-015', 4, 5, 'GPE'),
#  ('1071-002', 0, 1, 'GPE'),
#  ('1071-005', 0, 1, 'GPE'),
#  ('1072-009', 11, 13, 'CARDINAL'),
#  ('1073-008', 2, 4, 'CARDINAL'),
#  ('1076-002', 2, 3, 'NORP'),
#  ('1076-030', 0, 1, 'ORG'),
#  ('1076-035', 0, 1, 'ORG'),
#  ('1077-002', 0, 1, 'GPE'),
#  ('1077-003', 16, 17, 'GPE'),
#  ('1079-005', 7, 8, 'GPE'),
#  ('1079-007', 2, 3, 'GPE'),
#  ('1080-004', 0, 1, 'GPE'),
#  ('1082-002', 13, 14, 'NORP'),
#  ('1083-002', 6, 7, 'GPE'),
#  ('1084-002', 0, 1, 'GPE'),
#  ('1085-002', 2, 3, 'GPE'),
#  ('1086-002', 0, 1, 'GPE'),
#  ('1087-008', 1, 2, 'NORP'),
#  ('1087-018', 14, 15, 'GPE'),
#  ('1088-002', 27, 28, 'GPE'),
#  ('1089-002', 3, 4, 'GPE'),
#  ('1090-000', 4, 5, 'GPE'),
#  ('1090-004', 7, 8, 'GPE'),
#  ('1090-005', 15, 16, 'GPE'),
#  ('1090-010', 21, 22, 'GPE'),
#  ('1090-011', 17, 18, 'GPE'),
#  ('1091-004', 17, 18, 'GPE'),
#  ('1092-007', 0, 1, 'GPE'),
#  ('1093-002', 4, 6, 'GPE'),
#  ('1093-004', 0, 1, 'GPE'),
#  ('1093-005', 0, 2, 'GPE'),
#  ('1094-015', 0, 1, 'ORG'),
#  ('1094-019', 0, 1, 'ORG'),
#  ('1094-022', 0, 1, 'GPE'),
#  ('1094-027', 0, 1, 'ORG'),
#  ('1094-028', 2, 3, 'ORG'),
#  ('1094-033', 0, 1, 'ORG'),
#  ('1094-035', 0, 1, 'GPE'),
#  ('1094-053', 0, 1, 'GPE'),
#  ('1095-006', 0, 1, 'GPE'),
#  ('1095-008', 2, 3, 'GPE'),
#  ('1095-009', 3, 4, 'GPE'),
#  ('1095-011', 0, 1, 'GPE'),
#  ('1095-013', 2, 3, 'GPE'),
#  ('1095-014', 0, 1, 'GPE'),
#  ('1095-015', 0, 1, 'GPE'),
#  ('1095-018', 0, 1, 'GPE'),
#  ('1097-004', 21, 22, 'NORP'),
#  ('1098-002', 0, 1, 'GPE'),
#  ('1099-003', 0, 1, 'GPE'),
#  ('1099-004', 0, 1, 'GPE'),
#  ('1099-008', 1, 2, 'GPE'),
#  ('1099-009', 7, 8, 'NORP'),
#  ('1099-010', 17, 18, 'NORP'),
#  ('1099-015', 2, 4, 'GPE'),
#  ('1101-000', 2, 3, 'GPE'),
#  ('1101-005', 13, 14, 'NORP'),
#  ('1101-006', 16, 17, 'ORG'),
#  ('1101-007', 2, 3, 'ORG'),
#  ('1101-008', 9, 10, 'ORG'),
#  ('1101-009', 7, 8, 'GPE'),
#  ('1101-011', 0, 1, 'GPE'),
#  ('1101-012', 0, 1, 'GPE'),
#  ('1102-002', 0, 1, 'GPE'),
#  ('1103-003', 15, 16, 'GPE'),
#  ('1103-004', 0, 1, 'NORP'),
#  ('1103-006', 25, 26, 'NORP'),
#  ('1103-011', 15, 16, 'GPE'),
#  ('1103-013', 0, 1, 'GPE'),
#  ('1103-016', 0, 1, 'GPE'),
#  ('1103-018', 8, 9, 'NORP'),
#  ('1104-002', 6, 7, 'NORP'),
#  ('1105-003', 0, 1, 'NORP'),
#  ('1106-002', 2, 3, 'GPE'),
#  ('1106-007', 0, 1, 'GPE'),
#  ('1108-003', 0, 1, 'ORG'),
#  ('1108-004', 8, 9, 'ORG'),
#  ('1108-005', 0, 1, 'ORG'),
#  ('1109-003', 0, 1, 'GPE'),
#  ('1109-007', 0, 1, 'GPE'),
#  ('1112-002', 16, 17, 'GPE'),
#  ('1112-004', 8, 9, 'GPE'),
#  ('1112-008', 23, 25, 'ORG'),
#  ('1114-002', 7, 8, 'GPE'),
#  ('1115-001', 0, 1, 'GPE'),
#  ('1115-002', 1, 2, 'NORP'),
#  ('1115-010', 1, 2, 'GPE'),
#  ('1116-000', 0, 1, 'ORG'),
#  ('1116-001', 0, 1, 'GPE'),
#  ('1116-005', 14, 15, 'LOC'),
#  ('1116-006', 14, 15, 'NORP'),
#  ('1116-007', 16, 17, 'GPE'),
#  ('1116-009', 6, 7, 'GPE'),
#  ('1116-010', 0, 1, 'ORG'),
#  ('1116-011', 14, 15, 'GPE'),
#  ('1116-016', 3, 4, 'GPE'),
#  ('1116-021', 0, 1, 'NORP'),
#  ('1116-024', 0, 1, 'GPE'),
#  ('1116-027', 20, 21, 'GPE'),
#  ('1116-032', 10, 11, 'NORP'),
#  ('1116-033', 6, 7, 'NORP'),
#  ('1116-034', 0, 1, 'GPE'),
#  ('1116-035', 2, 3, 'NORP'),
#  ('1116-036', 15, 16, 'LOC'),
#  ('1116-037', 25, 26, 'NORP'),
#  ('1116-038', 14, 15, 'GPE'),
#  ('1117-000', 1, 2, 'NORP'),
#  ('1117-001', 0, 1, 'GPE'),
#  ('1117-002', 2, 3, 'NORP'),
#  ('1117-003', 0, 2, 'CARDINAL'),
#  ('1117-004', 7, 8, 'GPE'),
#  ('1117-005', 27, 28, 'GPE'),
#  ('1117-006', 0, 1, 'GPE'),
#  ('1117-007', 8, 9, 'GPE'),
#  ('1117-008', 5, 6, 'GPE'),
#  ('1118-000', 0, 3, 'GPE'),
#  ('1118-002', 16, 17, 'NORP'),
#  ('1118-003', 7, 8, 'NORP'),
#  ('1118-007', 7, 8, 'NORP'),
#  ('1119-000', 0, 1, 'GPE'),
#  ('1119-001', 0, 1, 'GPE'),
#  ('1119-002', 4, 5, 'NORP'),
#  ('1119-003', 3, 4, 'NORP'),
#  ('1119-005', 0, 1, 'ORG'),
#  ('1119-006', 21, 22, 'NORP'),
#  ('1119-007', 7, 8, 'NORP'),
#  ('1120-000', 1, 2, 'NORP'),
#  ('1120-001', 0, 1, 'GPE'),
#  ('1120-002', 16, 17, 'GPE'),
#  ('1120-005', 14, 15, 'GPE'),
#  ('1120-006', 17, 18, 'GPE'),
#  ('1120-007', 7, 8, 'GPE'),
#  ('1120-008', 12, 13, 'GPE'),
#  ('1121-000', 7, 8, 'GPE'),
#  ('1121-001', 0, 1, 'GPE'),
#  ('1121-002', 22, 23, 'NORP'),
#  ('1121-003', 41, 42, 'GPE'),
#  ('1121-004', 34, 35, 'ORG'),
#  ('1121-006', 11, 12, 'NORP'),
#  ('1121-007', 7, 8, 'GPE'),
#  ('1121-008', 17, 18, 'GPE'),
#  ('1122-000', 3, 4, 'GPE'),
#  ('1122-001', 0, 1, 'GPE'),
#  ('1122-002', 18, 19, 'NORP'),
#  ('1122-003', 10, 11, 'ORG'),
#  ('1122-004', 11, 12, 'GPE'),
#  ('1123-004', 2, 3, 'ORG'),
#  ('1123-010', 0, 1, 'ORG'),
#  ('1124-005', 5, 6, 'NORP'),
#  ('1124-010', 35, 36, 'NORP'),
#  ('1125-003', 16, 17, 'ORG'),
#  ('1125-004', 2, 3, 'ORG'),
#  ('1125-006', 0, 1, 'ORG'),
#  ('1125-007', 10, 11, 'GPE'),
#  ('1125-008', 14, 15, 'GPE'),
#  ('1125-010', 0, 1, 'ORG'),
#  ('1126-000', 0, 1, 'ORG'),
#  ('1126-001', 0, 1, 'ORG'),
#  ('1126-002', 33, 34, 'NORP'),
#  ('1126-004', 14, 15, 'ORG'),
#  ('1126-006', 3, 4, 'ORG'),
#  ('1126-007', 0, 1, 'NORP'),
#  ('1126-008', 1, 2, 'NORP'),
#  ('1126-009', 14, 15, 'ORG'),
#  ('1126-010', 24, 25, 'ORG'),
#  ('1127-002', 0, 1, 'GPE'),
#  ('1127-008', 0, 1, 'NORP'),
#  ('1127-009', 9, 10, 'GPE'),
#  ('1127-012', 12, 14, 'GPE'),
#  ('1128-000', 0, 1, 'NORP'),
#  ('1128-002', 15, 16, 'GPE'),
#  ('1128-003', 17, 18, 'NORP'),
#  ('1128-006', 5, 6, 'ORG'),
#  ('1128-007', 10, 11, 'GPE'),
#  ('1128-011', 1, 2, 'GPE'),
#  ('1128-012', 9, 10, 'NORP'),
#  ('1128-014', 0, 1, 'ORG'),
#  ('1129-000', 1, 2, 'NORP'),
#  ('1129-002', 1, 2, 'NORP'),
#  ('1129-004', 8, 9, 'ORG'),
#  ('1129-005', 12, 13, 'GPE'),
#  ('1130-006', 17, 18, 'GPE'),
#  ('1131-000', 0, 1, 'ORG'),
#  ('1131-002', 1, 2, 'GPE'),
#  ('1131-003', 30, 31, 'GPE'),
#  ('1131-004', 14, 15, 'GPE'),
#  ('1131-006', 15, 16, 'GPE'),
#  ('1132-000', 4, 5, 'NORP'),
#  ('1132-002', 12, 13, 'NORP'),
#  ('1132-004', 0, 2, 'ORG'),
#  ('1132-005', 0, 1, 'ORG'),
#  ('1132-007', 23, 24, 'NORP'),
#  ('1133-000', 0, 1, 'GPE'),
#  ('1133-005', 1, 2, 'GPE'),
#  ('1133-007', 4, 5, 'ORG'),
#  ('1133-008', 14, 15, 'GPE'),
#  ('1133-011', 6, 7, 'GPE'),
#  ('1133-012', 0, 1, 'ORG'),
#  ('1133-013', 0, 1, 'ORG'),
#  ('1133-014', 2, 3, 'ORG'),
#  ('1134-002', 0, 1, 'NORP'),
#  ('1134-005', 0, 1, 'GPE'),
#  ('1135-014', 6, 7, 'ORG'),
#  ('1135-027', 6, 7, 'ORG'),
#  ('1136-002', 19, 20, 'GPE'),
#  ('1136-005', 0, 1, 'GPE'),
#  ('1137-000', 0, 2, 'GPE'),
#  ('1138-000', 0, 1, 'NORP'),
#  ('1138-002', 0, 1, 'NORP'),
#  ('1138-003', 17, 18, 'ORG'),
#  ('1138-004', 6, 7, 'ORG'),
#  ('1138-005', 6, 7, 'ORG'),
#  ('1138-006', 0, 1, 'ORG'),
#  ('1138-007', 3, 4, 'ORG'),
#  ('1138-008', 3, 4, 'ORG'),
#  ('1138-010', 19, 20, 'GPE'),
#  ('1138-011', 0, 1, 'NORP'),
#  ('1139-003', 2, 3, 'ORG'),
#  ('1139-004', 4, 5, 'ORG'),
#  ('1139-005', 0, 1, 'ORG'),
#  ('1139-006', 3, 4, 'ORG'),
#  ('1139-008', 20, 21, 'GPE'),
#  ('1140-005', 15, 16, 'GPE'),
#  ('1141-000', 0, 1, 'GPE'),
#  ('1141-002', 1, 2, 'NORP'),
#  ('1141-006', 0, 1, 'GPE'),
#  ('1141-007', 3, 4, 'GPE'),
#  ('1141-008', 0, 1, 'GPE'),
#  ('1142-000', 3, 4, 'NORP'),
#  ('1142-002', 16, 17, 'GPE'),
#  ('1142-009', 11, 12, 'NORP'),
#  ('1142-012', 8, 9, 'GPE'),
#  ('1142-013', 1, 2, 'GPE'),
#  ('1142-014', 11, 12, 'NORP'),
#  ('1143-000', 6, 7, 'GPE'),
#  ('1143-002', 21, 22, 'NORP'),
#  ('1143-003', 14, 15, 'GPE'),
#  ('1143-004', 21, 22, 'ORG'),
#  ('1143-005', 6, 7, 'NORP'),
#  ('1143-006', 23, 24, 'GPE'),
#  ('1143-007', 17, 18, 'NORP'),
#  ('1143-008', 2, 3, 'NORP'),
#  ('1143-009', 14, 15, 'GPE'),
#  ('1144-000', 2, 3, 'NORP'),
#  ('1144-002', 38, 39, 'GPE'),
#  ('1144-004', 25, 26, 'ORG'),
#  ('1146-000', 0, 1, 'GPE'),
#  ('1146-002', 16, 17, 'GPE'),
#  ('1146-005', 23, 24, 'GPE'),
#  ('1146-006', 2, 3, 'ORG'),
#  ('1146-007', 17, 18, 'NORP'),
#  ('1147-002', 13, 14, 'GPE'),
#  ('1147-003', 3, 6, 'ORG'),
#  ('1147-006', 23, 24, 'ORG'),
#  ('1148-002', 7, 8, 'NORP'),
#  ('1148-003', 0, 1, 'ORG'),
#  ('1148-005', 8, 9, 'NORP'),
#  ('1149-000', 2, 3, 'GPE'),
#  ('1150-001', 0, 1, 'ORG'),
#  ('1150-006', 2, 3, 'GPE'),
#  ('1151-000', 6, 7, 'GPE'),
#  ('1151-002', 6, 7, 'GPE'),
#  ('1151-006', 20, 21, 'GPE'),
#  ('1152-000', 0, 1, 'GPE'),
#  ('1152-002', 0, 1, 'GPE'),
#  ('1152-005', 32, 33, 'ORG'),
#  ('1152-007', 27, 28, 'NORP'),
#  ('1152-008', 19, 20, 'GPE'),
#  ('1152-010', 1, 2, 'GPE'),
#  ('1152-011', 21, 22, 'GPE'),
#  ('1152-012', 11, 12, 'GPE'),
#  ('1152-013', 5, 6, 'GPE'),
#  ('1152-016', 2, 3, 'GPE'),
#  ('1152-017', 3, 4, 'ORG'),
#  ('1153-000', 2, 3, 'NORP'),
#  ('1153-002', 1, 2, 'NORP'),
#  ('1153-007', 30, 31, 'GPE'),
#  ('1154-000', 0, 1, 'GPE'),
#  ('1154-002', 16, 17, 'NORP'),
#  ('1154-008', 33, 34, 'ORG'),
#  ('1154-009', 11, 12, 'ORG'),
#  ('1155-000', 8, 9, 'GPE'),
#  ('1155-002', 24, 25, 'GPE'),
#  ('1155-003', 30, 31, 'NORP'),
#  ('1155-005', 14, 15, 'GPE'),
#  ('1155-006', 1, 2, 'NORP'),
#  ('1155-007', 0, 1, 'GPE'),
#  ('1155-009', 15, 16, 'GPE'),
#  ('1155-010', 17, 18, 'NORP'),
#  ('1155-011', 3, 4, 'GPE'),
#  ('1155-012', 7, 8, 'GPE'),
#  ('1155-013', 1, 2, 'GPE'),
#  ('1156-002', 9, 10, 'NORP'),
#  ('1156-007', 2, 3, 'GPE'),
#  ('1157-000', 6, 7, 'GPE'),
#  ('1157-002', 19, 20, 'GPE'),
#  ('1157-003', 2, 3, 'ORG'),
#  ('1157-004', 13, 16, 'ORG'),
#  ('1158-000', 5, 6, 'GPE'),
#  ('1158-002', 7, 8, 'ORG'),
#  ('1158-003', 10, 11, 'ORG'),
#  ('1158-005', 17, 18, 'ORG'),
#  ('1159-000', 7, 8, 'GPE'),
#  ('1159-002', 0, 1, 'NORP'),
#  ('1159-005', 26, 27, 'GPE'),
#  ('1160-000', 5, 6, 'GPE'),
#  ('1160-002', 2, 3, 'GPE'),
#  ('1160-006', 0, 1, 'GPE'),
#  ('1160-011', 28, 29, 'GPE'),
#  ('1160-014', 0, 1, 'ORG'),
#  ('1160-016', 9, 10, 'GPE'),
#  ('1160-018', 16, 17, 'GPE'),
#  ('1160-022', 31, 32, 'GPE'),
#  ('1160-023', 33, 34, 'GPE'),
#  ('1160-024', 19, 20, 'GPE'),
#  ('1161-007', 5, 6, 'ORG')}

# %%
mentions_dev_gold = set(gold_mentions(df_dev))
print(len(mentions_dev_gold))
# Out:
# 5917

# %%
mentions_dev_gold
# Out:
# {('1076-009', 0, 1, 'FK_Budućnost_Podgorica'),
#  ('1137-003', 19, 23, '--NME--'),
#  ('1003-003', 45, 46, 'Paramaribo'),
#  ('1143-003', 39, 44, 'United_Nations_Interim_Force_in_Lebanon'),
#  ('0957-006', 2, 4, 'Goran_Ivanišević'),
#  ('0972-006', 0, 2, '--NME--'),
#  ('0966-074', 4, 5, 'Kenya'),
#  ('1010-002', 2, 4, 'Joseph_Bernardin'),
#  ('1152-015', 7, 9, 'United_States_Air_Force'),
#  ('1079-007', 5, 7, 'KK_Crvena_zvezda'),
#  ('0980-013', 28, 32, 'Federal_Open_Market_Committee'),
#  ('1148-005', 8, 9, 'Tunisia'),
#  ('1069-013', 21, 23, '--NME--'),
#  ('1114-004', 2, 4, 'Cosmin_Contra'),
#  ('1068-029', 0, 2, 'Cambridge_United_F.C.'),
#  ('0958-015', 0, 1, 'Minnesota_Twins'),
#  ('0961-007', 17, 19, 'Jeffrey_Lurie'),
#  ('1046-004', 30, 31, 'Donato_(footballer)'),
#  ('1090-017', 5, 6, 'Monica_Seles'),
#  ('1041-001', 0, 1, 'Tokyo'),
#  ('1141-002', 21, 23, 'China_Daily'),
#  ('0947-009', 18, 19, 'Lancashire_County_Cricket_Club'),
#  ('0966-121', 4, 5, 'France'),
#  ('1086-003', 2, 4, 'Bruce_Dyer'),
#  ('1016-005', 11, 13, 'Benjamin_Netanyahu'),
#  ('1025-011', 2, 3, '--NME--'),
#  ('1057-003', 2, 4, 'Adam_Hollioake'),
#  ('1155-014', 0, 1, 'Germany'),
#  ('0946-014', 9, 11, 'Paul_Johnson_(cricketer)'),
#  ('1016-011', 9, 11, 'Middle_East'),
#  ('1034-006', 0, 1, 'Annemarie_Jorritsma'),
#  ('1112-008', 1, 3, 'Berti_Vogts'),
#  ('1066-019', 0, 1, 'Birmingham_City_F.C.'),
#  ('0990-007', 28, 29, 'Chechnya'),
#  ('0990-008', 0, 1, 'Alexander_Lebed'),
#  ('0965-007', 25, 26, 'Brussels'),
#  ('1006-009', 27, 28, 'Reuters'),
#  ('0996-006', 11, 12, 'Belgrade'),
#  ('1142-012', 4, 5, 'Kurdistan_Democratic_Party'),
#  ('0962-011', 6, 8, 'Tiger_Woods'),
#  ('1142-001', 0, 1, 'Istanbul'),
#  ('1050-003', 8, 10, '--NME--'),
#  ('1068-028', 0, 1, 'Brighton_&_Hove_Albion_F.C.'),
#  ('1081-002', 0, 1, 'Armenia_national_football_team'),
#  ('1078-007', 5, 7, 'KK_Crvena_zvezda'),
#  ('1060-022', 1, 4, 'Miguel_Ángel_Martín_(golfer)'),
#  ('1160-000', 1, 2, 'Irish_Republican_Army'),
#  ('1000-011', 13, 14, '--NME--'),
#  ('1006-004', 38, 40, 'Pan_American_World_Airways'),
#  ('0947-000', 2, 5, 'County_Championship'),
#  ('1046-009', 15, 16, 'Brazil'),
#  ('1141-003', 10, 11, 'Hubei'),
#  ('1060-001', 0, 1, 'London'),
#  ('0961-008', 7, 8, 'Randall_Cunningham'),
#  ('1096-031', 1, 3, 'New_York_City'),
#  ('1123-009', 0, 1, 'Hanwha_Eagles'),
#  ('1159-003', 15, 16, 'Liège'),
#  ('0990-006', 0, 1, 'Alexander_Lebed'),
#  ('0960-028', 4, 5, 'Jeff_Tarango'),
#  ('1160-014', 0, 1, '--NME--'),
#  ('0955-011', 0, 1, 'Pohang_Steelers'),
#  ('1009-015', 35, 36, 'Mexico'),
#  ('0960-009', 0, 1, 'MaliVai_Washington'),
#  ('1065-019', 0, 1, 'Ayr_United_F.C.'),
#  ('1103-016', 27, 29, 'Ogün_Temizkanoğlu'),
#  ('1097-011', 21, 22, 'Bernd_Karbacher'),
#  ('0960-000', 2, 3, 'Jeff_Tarango'),
#  ('1101-012', 88, 90, 'Francisco_Palencia'),
#  ('1106-007', 0, 1, 'Turkey_national_football_team'),
#  ('1009-010', 26, 27, 'Mexico'),
#  ('1031-004', 4, 6, '--NME--'),
#  ('1070-013', 8, 10, '--NME--'),
#  ('1141-003', 2, 3, 'Wuhan'),
#  ('0957-024', 3, 4, 'Germany'),
#  ('0979-013', 1, 3, '--NME--'),
#  ('1125-012', 29, 30, 'Rwanda'),
#  ('0990-010', 0, 1, 'Boris_Yeltsin'),
#  ('1040-001', 0, 1, 'Tokyo'),
#  ('0947-012', 14, 15, 'Northamptonshire_County_Cricket_Club'),
#  ('0966-077', 1, 3, 'Gunhild_Haugen'),
#  ('1096-036', 13, 15, 'Alan_Benes'),
#  ('1016-014', 12, 14, 'Ezer_Weizman'),
#  ('0970-002', 30, 31, 'Atalanta_B.C.'),
#  ('1141-000', 0, 1, 'China'),
#  ('1017-007', 34, 35, 'French_Democratic_Confederation_of_Labour'),
#  ('1144-002', 26, 27, 'Kurdistan'),
#  ('0981-004', 0, 1, 'Magna_International'),
#  ('1000-004', 14, 15, 'Budapest_Stock_Exchange'),
#  ('1051-009', 32, 34, 'Klas_Eriksson'),
#  ('1058-036', 15, 17, 'Tony_Clark'),
#  ('1141-002', 1, 2, 'China'),
#  ('0994-017', 13, 15, '--NME--'),
#  ('1113-006', 0, 1, 'MSV_Duisburg'),
#  ('0978-004', 0, 2, '--NME--'),
#  ('1077-003', 8, 9, '--NME--'),
#  ('1126-000', 2, 3, 'Islam'),
#  ('0966-084', 1, 3, 'Fabrizio_Mori'),
#  ('0963-004', 12, 15, 'United_States_Amateur_Championship_(golf)'),
#  ('1061-012', 0, 1, 'Bridgend_Ravens'),
#  ('0967-005', 0, 2, 'Roberto_Bisconti'),
#  ('1038-005', 8, 10, 'Hong_Kong'),
#  ('0984-016', 18, 19, 'Tokyo'),
#  ('1058-043', 0, 2, 'Matt_Lawton'),
#  ('1063-002', 11, 13, 'FIFA_World_Cup'),
#  ('1135-018', 0, 2, 'Aung_San_Suu_Kyi'),
#  ('1091-004', 14, 16, '--NME--'),
#  ('1011-013', 10, 12, 'First_Chicago_Bank'),
#  ('0963-023', 18, 22, 'NEC_World_Series_of_Golf'),
#  ('0996-001', 0, 1, 'Warsaw'),
#  ('1057-006', 20, 22, 'Adam_Hollioake'),
#  ('0980-016', 3, 4, 'Federal_Reserve'),
#  ('0956-016', 0, 1, 'Hanwha_Eagles'),
#  ('1128-011', 8, 9, '--NME--'),
#  ('1121-000', 3, 4, 'Iraq'),
#  ('1101-012', 35, 37, 'Germán_Villa'),
#  ('1068-038', 2, 3, 'Chester_City_F.C.'),
#  ('1111-006', 1, 2, '--NME--'),
#  ('1089-002', 0, 2, 'Jesper_Parnevik'),
#  ('0953-000', 4, 6, 'Roberto_Durán'),
#  ('1069-016', 1, 2, 'County_Cricket_Ground,_Hove'),
#  ('1072-015', 4, 7, '--NME--'),
#  ('0966-018', 4, 5, 'Russia'),
#  ('1056-037', 3, 4, 'France'),
#  ('0966-110', 4, 5, 'Germany'),
#  ('1005-001', 0, 2, '--NME--'),
#  ('1032-000', 0, 1, 'Netherlands'),
#  ('1144-004', 5, 6, 'Kurdistan_Democratic_Party'),
#  ('0972-002', 10, 11, 'Australia_national_cricket_team'),
#  ('0992-003', 15, 16, 'Party_of_Democratic_Action'),
#  ('1027-007', 0, 1, 'State_of_Palestine'),
#  ('1008-028', 0, 1, '--NME--'),
#  ('0978-000', 0, 2, '--NME--'),
#  ('1035-009', 2, 3, 'Interfax'),
#  ('0970-006', 4, 5, 'Atalanta_B.C.'),
#  ('1072-006', 0, 1, 'South_Africa_national_rugby_union_team'),
#  ('1097-011', 0, 1, 'Stefan_Edberg'),
#  ('0957-018', 9, 11, 'Cédric_Pioline'),
#  ('0997-004', 14, 15, 'Russia'),
#  ('1019-004', 17, 18, 'Netherlands'),
#  ('0966-148', 4, 5, 'Norway'),
#  ('1096-019', 6, 7, 'Chicago_Cubs'),
#  ('1056-006', 1, 3, 'Antonella_Bellutti'),
#  ('1066-073', 0, 2, 'Leyton_Orient_F.C.'),
#  ('0960-007', 29, 30, 'India'),
#  ('1134-002', 2, 4, 'Fidel_Ramos'),
#  ('1006-012', 12, 13, 'Benghazi'),
#  ('1025-010', 13, 14, 'Israel'),
#  ('0960-037', 3, 4, '--NME--'),
#  ('1045-004', 32, 33, '--NME--'),
#  ('0947-009', 0, 1, 'Hove'),
#  ('0966-145', 1, 3, 'Kenny_Harrison'),
#  ('1099-017', 43, 45, 'Andreas_Heraf'),
#  ('1046-003', 1, 2, 'Brazil'),
#  ('0946-006', 0, 1, 'Essex_County_Cricket_Club'),
#  ('1143-007', 26, 27, 'Lebanon'),
#  ('0966-009', 4, 5, 'Switzerland'),
#  ('1035-000', 7, 8, 'Germany'),
#  ('1113-006', 2, 3, '--NME--'),
#  ('1116-006', 31, 32, 'Italy'),
#  ('1083-002', 0, 1, 'Pallacanestro_Treviso'),
#  ('1115-006', 0, 1, '--NME--'),
#  ('1116-018', 6, 8, '--NME--'),
#  ('0966-096', 4, 5, 'Germany'),
#  ('1051-003', 22, 23, 'Robert_Allenby'),
#  ('1099-007', 15, 16, 'Austria'),
#  ('0947-006', 7, 9, '--NME--'),
#  ('0996-003', 1, 2, 'Dariusz_Rosati'),
#  ('0959-012', 2, 3, 'Colorado_Rockies'),
#  ('1131-007', 7, 8, 'Guatemala'),
#  ('1069-008', 0, 1, 'Glamorgan_County_Cricket_Club'),
#  ('1097-020', 10, 11, 'Stefan_Edberg'),
#  ('1103-015', 54, 56, 'Frédéric_Peiremans'),
#  ('0991-003', 20, 22, 'Chechnya'),
#  ('1060-022', 5, 6, 'Spain'),
#  ('0966-019', 1, 3, '--NME--'),
#  ('0991-005', 11, 12, 'Alexander_Lebed'),
#  ('0958-019', 0, 1, 'Texas_Rangers_(baseball)'),
#  ('0972-021', 8, 9, 'Upul_Chandana'),
#  ('1057-000', 2, 3, 'Pakistan_national_cricket_team'),
#  ('1049-003', 29, 31, 'Niall_Quinn'),
#  ('1090-010', 4, 5, 'Austria_Fed_Cup_team'),
#  ('1060-004', 2, 3, 'United_Kingdom'),
#  ('1092-007', 13, 15, '--NME--'),
#  ('1061-015', 2, 3, 'Caerphilly_RFC'),
#  ('1060-015', 4, 5, 'Trinidad'),
#  ('1017-012', 16, 17, '--NME--'),
#  ('1061-000', 5, 6, 'Scotland'),
#  ('0997-008', 2, 3, 'Boris_Yeltsin'),
#  ('1055-019', 0, 1, 'Ata-ur-Rahman'),
#  ('1125-002', 15, 16, 'Democratic_Republic_of_the_Congo'),
#  ('1016-003', 12, 13, 'Jerusalem'),
#  ('1045-006', 30, 34, '--NME--'),
#  ('0958-055', 0, 2, 'San_Francisco_Giants'),
#  ('0994-017', 1, 3, 'United_States'),
#  ('0957-015', 5, 6, 'United_States'),
#  ('0966-036', 4, 5, 'Denmark'),
#  ('1055-026', 0, 1, 'Inzamam-ul-Haq'),
#  ('1101-008', 9, 10, 'Youri_Djorkaeff'),
#  ('0947-008', 0, 1, 'London'),
#  ('0946-012', 0, 1, 'Australia'),
#  ('1038-001', 0, 1, 'Auckland'),
#  ('1071-002', 0, 1, '--NME--'),
#  ('1160-003', 2, 4, 'Neil_Jordan'),
#  ('1121-008', 25, 26, 'Iraq'),
#  ('0984-005', 0, 1, 'United_Kingdom'),
#  ('1094-016', 0, 1, 'Milwaukee_Brewers'),
#  ('0966-026', 4, 5, 'United_States'),
#  ('0956-018', 0, 1, '--NME--'),
#  ('0970-003', 9, 10, 'Atalanta_B.C.'),
#  ('1016-003', 0, 1, 'Israel'),
#  ('1058-037', 14, 15, 'Kansas_City_Royals'),
#  ('1055-009', 0, 2, '--NME--'),
#  ('0956-009', 2, 3, '--NME--'),
#  ('0947-011', 7, 8, 'Derbyshire_County_Cricket_Club'),
#  ('1061-003', 0, 1, 'Wales'),
#  ('1119-000', 5, 6, 'Erbil'),
#  ('1069-013', 17, 19, '--NME--'),
#  ('1017-007', 36, 38, '--NME--'),
#  ('1048-001', 2, 3, 'Israel'),
#  ('1146-004', 8, 10, 'Jalal_Talabani'),
#  ('1116-022', 13, 16, 'Lawrence_of_Arabia_(film)'),
#  ('1066-017', 0, 2, 'Crystal_Palace_F.C.'),
#  ('0990-002', 10, 12, 'Boris_Yeltsin'),
#  ('0963-004', 0, 1, 'Tiger_Woods'),
#  ('1108-000', 4, 5, 'Nate_Miller'),
#  ('1044-000', 3, 4, 'Nablus'),
#  ('0966-152', 4, 5, 'Germany'),
#  ('1058-026', 16, 17, 'Seattle_Mariners'),
#  ('1156-002', 0, 1, 'Italy'),
#  ('1059-006', 6, 7, 'Surrey_County_Cricket_Club'),
#  ('0966-022', 4, 5, 'United_Kingdom'),
#  ('0979-001', 0, 2, 'New_York_City'),
#  ('1094-019', 0, 1, 'Texas_Rangers_(baseball)'),
#  ('1066-011', 0, 3, 'Queens_Park_Rangers_F.C.'),
#  ('0958-014', 0, 1, 'Chicago_White_Sox'),
#  ('1138-002', 10, 12, 'New_York'),
#  ('0965-009', 4, 5, 'Zürich'),
#  ('1077-002', 4, 6, 'Paul_Gascoigne'),
#  ('1123-012', 0, 1, '--NME--'),
#  ('0972-021', 5, 6, 'Sanath_Jayasuriya'),
#  ('1072-012', 5, 6, '--NME--'),
#  ('1095-008', 0, 1, 'Texas_Rangers_(baseball)'),
#  ('1031-011', 10, 11, 'China'),
#  ('0968-002', 21, 25, '--NME--'),
#  ('1125-000', 0, 1, 'Rwanda'),
#  ('1101-012', 9, 11, '--NME--'),
#  ('1061-006', 3, 4, 'Bristol_Bears'),
#  ('1049-000', 2, 3, 'Republic_of_Ireland_national_football_team'),
#  ('0972-013', 3, 4, 'Romesh_Kaluwitharana'),
#  ('1154-000', 0, 1, 'Algeria'),
#  ('1068-021', 0, 1, 'Gillingham_F.C.'),
#  ('0951-002', 2, 3, 'Lithuania_national_under-21_football_team'),
#  ('1043-000', 0, 1, 'Singapore'),
#  ('1160-001', 0, 2, '--NME--'),
#  ('1085-002', 2, 3, 'Estonia_national_football_team'),
#  ('1072-012', 24, 25, '--NME--'),
#  ('1113-005', 3, 5, 'FC_St._Pauli'),
#  ('1144-002', 7, 9, 'Masoud_Barzani'),
#  ('1007-022', 8, 10, 'Dow_Jones_Industrial_Average'),
#  ('1126-002', 19, 20, 'Bosnia_and_Herzegovina'),
#  ('1058-000', 6, 7, 'Texas_Rangers_(baseball)'),
#  ('0972-037', 0, 1, '--NME--'),
#  ('0963-003', 18, 20, 'Jesper_Parnevik'),
#  ('1096-017', 1, 2, 'Philadelphia_Phillies'),
#  ('0965-004', 6, 7, 'Olympic_sports'),
#  ('1096-022', 21, 23, 'Andruw_Jones'),
#  ('1066-051', 0, 1, 'Wrexham_A.F.C.'),
#  ('0965-006', 9, 10, 'Donovan_Bailey'),
#  ('1019-000', 6, 7, 'Netherlands'),
#  ('1137-002', 24, 25, 'Seoul'),
#  ('1068-017', 0, 1, 'A.F.C._Bournemouth'),
#  ('1030-040', 1, 2, 'Tokyo'),
#  ('1115-010', 3, 5, 'Ronald_Reagan'),
#  ('1152-016', 17, 18, 'United_States'),
#  ('1121-007', 1, 3, 'Bill_Clinton'),
#  ('1128-006', 34, 35, 'Poland'),
#  ('1090-000', 10, 13, '1997_Fed_Cup'),
#  ('0957-028', 10, 12, 'Czech_Republic'),
#  ('0966-099', 4, 5, 'United_States'),
#  ('1013-006', 1, 5, '--NME--'),
#  ('1096-032', 33, 34, 'San_Francisco_Giants'),
#  ('0972-040', 4, 5, 'India_national_cricket_team'),
#  ('1090-018', 17, 18, 'Spain_Fed_Cup_team'),
#  ('1072-018', 26, 29, '--NME--'),
#  ('0972-011', 0, 2, '--NME--'),
#  ('1060-020', 5, 6, 'Spain'),
#  ('0961-005', 7, 8, 'Philadelphia_Eagles'),
#  ('0992-007', 29, 30, 'Serbia'),
#  ('1065-000', 2, 3, 'Scotland'),
#  ('0955-010', 0, 1, '--NME--'),
#  ('1027-007', 2, 3, 'Yasser_Arafat'),
#  ('1054-008', 1, 3, 'Erik_Breukink'),
#  ('1148-000', 3, 4, 'Tunisia'),
#  ('1101-008', 3, 4, '--NME--'),
#  ('1022-010', 6, 7, 'Canada'),
#  ('0946-008', 13, 14, 'Peter_Such'),
#  ('0957-033', 15, 17, 'Andrea_Gaudenzi'),
#  ('1130-010', 7, 9, 'Prensa_Latina'),
#  ('0991-009', 1, 2, 'Russia'),
#  ('0946-010', 5, 6, 'England_cricket_team'),
#  ('1127-014', 29, 30, 'Urus-Martan'),
#  ('0966-073', 1, 3, 'Gete_Wami'),
#  ('1121-004', 34, 35, 'Reuters'),
#  ('1133-006', 22, 24, 'Amnesty_International'),
#  ('1056-021', 1, 3, 'Annett_Neumann'),
#  ('1009-004', 6, 7, 'Mexico'),
#  ('1044-004', 32, 33, 'Jews'),
#  ('1070-010', 4, 5, 'United_States'),
#  ('1044-006', 6, 8, 'East_Jerusalem'),
#  ('1044-004', 38, 39, 'Israel'),
#  ('1057-003', 11, 12, 'Lancashire_County_Cricket_Club'),
#  ('1011-005', 8, 9, 'Midwestern_United_States'),
#  ('0957-004', 3, 4, 'France'),
#  ('1089-019', 0, 1, '--NME--'),
#  ('1022-003', 31, 34, '--NME--'),
#  ('0983-006', 7, 8, '--NME--'),
#  ('0970-006', 24, 25, 'Torino_F.C.'),
#  ('1099-017', 20, 22, 'Dieter_Ramusch'),
#  ('1058-012', 0, 2, 'Jeff_Russell'),
#  ('1100-002', 1, 3, 'Tom_Johnson_(boxer)'),
#  ('1017-006', 8, 9, '--NME--'),
#  ('1066-035', 0, 1, 'Millwall_F.C.'),
#  ('1116-031', 10, 12, 'Cape_Town'),
#  ('1058-029', 0, 1, 'Harold_Baines'),
#  ('1013-004', 8, 9, 'Mediterranean_Sea'),
#  ('1058-026', 6, 8, 'Chicago_White_Sox'),
#  ('0968-003', 40, 41, '--NME--'),
#  ('1155-003', 18, 19, 'Iran'),
#  ('0986-006', 14, 15, 'Ray_Houghton'),
#  ('1072-018', 10, 12, '--NME--'),
#  ('1142-002', 5, 6, '--NME--'),
#  ('1142-002', 26, 27, 'Reuters'),
#  ('1059-005', 8, 9, 'Surrey_County_Cricket_Club'),
#  ('1152-000', 7, 8, 'Bill_Clinton'),
#  ('0985-004', 1, 2, 'United_Kingdom'),
#  ('0957-004', 9, 10, 'Argentina'),
#  ('1057-007', 0, 1, 'Pakistan_national_cricket_team'),
#  ('1005-003', 0, 2, '--NME--'),
#  ('1070-008', 7, 10, '--NME--'),
#  ('1064-005', 28, 29, 'Gloucester_Rugby'),
#  ('1126-002', 21, 22, 'Serbia'),
#  ('1007-029', 4, 6, 'Dow_Jones_Industrial_Average'),
#  ('1093-000', 4, 6, 'El_Salvador_national_football_team'),
#  ('1095-020', 0, 2, '--NME--'),
#  ('1011-006', 0, 2, '--NME--'),
#  ('1101-012', 0, 1, 'Mexico_national_football_team'),
#  ('1010-019', 8, 9, 'HIV/AIDS'),
#  ('1087-020', 19, 20, 'Rodney_Eyles'),
#  ('1054-023', 7, 8, 'TVM_(cycling_team)'),
#  ('1104-000', 5, 6, 'Spain'),
#  ('0980-009', 4, 6, 'Federal_Reserve'),
#  ('1066-067', 0, 1, 'Barnet_F.C.'),
#  ('0947-003', 2, 3, 'Leicestershire_County_Cricket_Club'),
#  ('1156-004', 23, 24, 'Burundi'),
#  ('0947-004', 5, 7, '--NME--'),
#  ('1051-008', 1, 3, 'Joakim_Haeggman'),
#  ('0966-054', 4, 5, 'Germany'),
#  ('0965-009', 0, 1, 'Berlin'),
#  ('0966-123', 1, 3, 'Dmitri_Markov'),
#  ('1068-031', 0, 1, 'Doncaster_Rovers_F.C.'),
#  ('1030-013', 14, 15, 'Japan'),
#  ('1148-006', 1, 2, 'Tunisia'),
#  ('1068-026', 4, 5, 'Wrexham_A.F.C.'),
#  ('0967-002', 0, 1, 'UEFA'),
#  ('1037-004', 3, 4, '--NME--'),
#  ('1037-002', 3, 6, '--NME--'),
#  ('1132-007', 10, 13, 'Popular_Revolutionary_Army'),
#  ('0984-001', 0, 1, 'London'),
#  ('0967-003', 1, 2, 'Belgium'),
#  ('0971-001', 0, 1, 'Colombo'),
#  ('1076-008', 2, 3, 'FK_Vojvodina'),
#  ('0990-012', 8, 9, 'Boris_Yeltsin'),
#  ('1055-020', 2, 4, '--NME--'),
#  ('0980-005', 21, 22, 'Eurodollar'),
#  ('1065-036', 0, 2, 'East_Stirlingshire_F.C.'),
#  ('1116-037', 25, 26, 'Russia'),
#  ('1094-038', 0, 2, 'National_League_Central'),
#  ('1154-008', 0, 1, 'Algeria'),
#  ('1015-001', 0, 2, 'New_York_City'),
#  ('1025-012', 7, 8, 'Israel'),
#  ('1040-009', 2, 5, '--NME--'),
#  ('1132-002', 12, 13, 'Mexico'),
#  ('1057-002', 18, 19, 'Edgbaston'),
#  ('1103-006', 14, 15, '--NME--'),
#  ('0972-040', 6, 7, 'Zimbabwe_national_cricket_team'),
#  ('1126-000', 0, 1, 'NATO'),
#  ('1058-019', 5, 6, 'New_York_Yankees'),
#  ('0994-014', 5, 6, 'Moscow'),
#  ('1076-028', 0, 1, 'FK_Rudar_Ugljevik'),
#  ('1121-003', 1, 2, 'London'),
#  ('1058-022', 20, 22, 'Baltimore_Orioles'),
#  ('1134-000', 0, 1, '--NME--'),
#  ('1072-005', 33, 35, 'South_Africa_national_rugby_union_team'),
#  ('1016-010', 5, 6, 'Israel'),
#  ('0989-001', 0, 1, '--NME--'),
#  ('1114-001', 0, 1, 'Bucharest'),
#  ('1020-008', 1, 3, '--NME--'),
#  ('1028-012', 8, 9, 'Detroit'),
#  ('1046-001', 3, 4, 'Spain'),
#  ('0954-004', 2, 4, 'Peter_Nicol'),
#  ('1096-032', 18, 20, 'Pete_Harnisch'),
#  ('0947-008', 18, 20, '--NME--'),
#  ('1016-012', 0, 1, '--NME--'),
#  ('1154-009', 11, 12, 'Islam'),
#  ('1115-003', 0, 3, 'The_Sunday_Telegraph'),
#  ('1014-009', 6, 7, 'Bob_Dole'),
#  ('0994-001', 0, 2, '--NME--'),
#  ('0968-004', 43, 44, 'Milan'),
#  ('0968-004', 24, 25, 'Bosnia_and_Herzegovina'),
#  ('1044-007', 22, 23, 'Jerusalem'),
#  ('0965-006', 2, 4, 'Michael_Green_(sprinter)'),
#  ('1056-032', 1, 3, '--NME--'),
#  ('1138-003', 10, 11, 'Zhejiang'),
#  ('0966-057', 4, 5, 'Belarus'),
#  ('0948-045', 3, 4, 'Kent_County_Cricket_Club'),
#  ('0958-056', 0, 1, 'Colorado_Rockies'),
#  ('1140-005', 15, 16, 'China'),
#  ('1057-003', 0, 1, 'Surrey_County_Cricket_Club'),
#  ('1052-002', 3, 5, 'Faroe_Islands_national_football_team'),
#  ('1094-046', 0, 2, 'Los_Angeles_Angels'),
#  ('1027-011', 1, 2, '--NME--'),
#  ('0958-011', 0, 1, 'Detroit_Tigers'),
#  ('1010-006', 4, 5, 'Chicago'),
#  ('1031-007', 38, 39, '--NME--'),
#  ('1079-000', 2, 5, '--NME--'),
#  ('0983-002', 1, 2, 'Iraq'),
#  ('0993-004', 3, 4, 'Surčin'),
#  ('1112-008', 23, 25, 'UEFA_Euro_1996'),
#  ('1058-002', 0, 2, 'Juan_González_(baseball)'),
#  ('1115-008', 30, 31, 'Margaret_Thatcher'),
#  ('1058-024', 2, 4, 'Eddie_Murray'),
#  ('1124-009', 30, 31, 'France'),
#  ('1097-007', 7, 9, 'Ivan_Lendl'),
#  ('1030-039', 4, 6, 'FTSE_100_Index'),
#  ('1095-007', 0, 1, 'Milwaukee_Brewers'),
#  ('0957-008', 0, 2, 'Mark_Philippoussis'),
#  ('1068-013', 4, 5, 'Barnsley_F.C.'),
#  ('1054-008', 6, 7, 'Team_Jumbo–Visma'),
#  ('1051-010', 25, 27, 'Mark_Roe'),
#  ('1076-014', 0, 1, 'FK_Partizan'),
#  ('1094-021', 0, 1, 'Oakland_Athletics'),
#  ('1016-013', 10, 12, 'Volker_Rühe'),
#  ('1005-004', 1, 3, 'Southeast_Asia'),
#  ('1012-004', 17, 18, 'Libya'),
#  ('1046-005', 0, 1, 'Real_Madrid_CF'),
#  ('1039-018', 21, 23, 'Megawati_Sukarnoputri'),
#  ('1036-017', 9, 10, 'Barentsburg'),
#  ('0961-008', 30, 31, 'National_Football_League'),
#  ('1093-002', 4, 6, 'El_Salvador_national_football_team'),
#  ('0966-093', 1, 3, 'Anja_Rücker'),
#  ('1009-003', 0, 3, 'United_States_Department_of_Agriculture'),
#  ('0980-014', 16, 17, 'United_States'),
#  ('0965-004', 16, 17, 'Dennis_Mitchell'),
#  ('1066-034', 0, 1, 'Chesterfield_F.C.'),
#  ('1123-007', 0, 1, '--NME--'),
#  ('0989-002', 3, 4, '--NME--'),
#  ('0984-012', 18, 21, '--NME--'),
#  ('0966-134', 4, 5, 'Kenya'),
#  ('1007-000', 3, 5, 'New_York_Stock_Exchange'),
#  ('1110-002', 1, 3, 'Nate_Miller'),
#  ('1011-010', 13, 14, '--NME--'),
#  ('1156-000', 4, 5, 'Burundi'),
#  ('1116-035', 2, 3, 'United_Kingdom'),
#  ('1126-004', 11, 12, 'Mahala'),
#  ('1152-014', 5, 8, '--NME--'),
#  ('1063-000', 4, 6, 'Northern_Ireland_national_football_team'),
#  ('1095-016', 3, 4, 'Montreal_Expos'),
#  ('1091-004', 8, 10, 'Thomas_Enqvist'),
#  ('1127-008', 18, 19, 'Russia'),
#  ('1017-007', 13, 15, 'Christian_Blanc'),
#  ('1056-020', 1, 3, 'Félicia_Ballanger'),
#  ('1154-009', 29, 30, 'Islamism'),
#  ('1081-000', 4, 5, 'Portugal_national_football_team'),
#  ('0991-007', 29, 30, 'Chechnya'),
#  ('1114-005', 2, 4, '--NME--'),
#  ('1000-009', 10, 11, 'Budapest'),
#  ('0966-087', 4, 5, 'Australia'),
#  ('1036-031', 14, 15, 'Norway'),
#  ('0947-003', 0, 1, 'Leicester'),
#  ('0966-024', 1, 3, 'Emilio_Valle'),
#  ('1027-017', 20, 21, 'Jordan'),
#  ('1128-009', 14, 15, 'Poland'),
#  ('1035-009', 15, 16, 'Germany'),
#  ('1101-011', 0, 1, 'France_national_football_team'),
#  ('1033-003', 32, 33, 'Russia'),
#  ('1015-000', 0, 1, 'RMS_Titanic'),
#  ('1049-003', 33, 35, 'Ian_Harte'),
#  ('1120-005', 19, 20, 'Jordan'),
#  ('1051-001', 0, 1, 'Northampton'),
#  ('0957-004', 0, 2, 'Sandrine_Testud'),
#  ('1011-018', 3, 4, 'Missouri'),
#  ('1118-006', 21, 23, 'Conservative_Party_(UK)'),
#  ('1155-010', 17, 18, 'Iran'),
#  ('1148-002', 7, 8, 'Tunisia'),
#  ('1077-000', 2, 3, 'Paul_Ince'),
#  ('1054-013', 4, 5, 'Sweden'),
#  ('1121-007', 32, 33, 'Iraq'),
#  ('1098-000', 3, 4, 'Naseem_Hamed'),
#  ('1094-053', 0, 1, 'Miami_Marlins'),
#  ('1152-011', 0, 1, 'Bill_Clinton'),
#  ('0986-006', 20, 21, '--NME--'),
#  ('1142-005', 24, 25, 'Ankara'),
#  ('0949-010', 2, 4, 'UEFA_Euro_1996'),
#  ('0957-004', 6, 8, 'Inés_Gorrochategui'),
#  ('1056-017', 8, 10, '--NME--'),
#  ('0981-006', 8, 9, 'Magna_International'),
#  ('1093-001', 0, 2, 'Los_Angeles'),
#  ('1103-020', 15, 16, 'Russia_national_football_team'),
#  ('0957-021', 16, 17, 'United_States'),
#  ('0966-081', 1, 3, 'Torrance_Zellner'),
#  ('0952-003', 4, 5, 'Russia'),
#  ('0981-001', 3, 4, '--NME--'),
#  ('1090-018', 26, 28, 'Conchita_Martínez'),
#  ('1036-014', 0, 1, '--NME--'),
#  ('0970-006', 6, 7, 'Gianluigi_Lentini'),
#  ('1072-018', 18, 20, 'Joel_Stransky'),
#  ('1069-010', 20, 21, 'Derbyshire_County_Cricket_Club'),
#  ('1054-010', 4, 5, 'Russia'),
#  ('0947-007', 15, 16, 'Kent_County_Cricket_Club'),
#  ('1132-004', 7, 8, '--NME--'),
#  ('1160-014', 20, 23, '--NME--'),
#  ('1000-018', 26, 27, '--NME--'),
#  ('1066-075', 0, 1, 'Hereford_United_F.C.'),
#  ('1089-026', 30, 31, 'Greg_Kraft'),
#  ('1103-015', 62, 64, 'Marc_Degryse'),
#  ('1033-013', 12, 13, 'Russia'),
#  ('1058-006', 0, 1, '--NME--'),
#  ('0968-004', 0, 2, '1996_Summer_Olympics'),
#  ('1008-023', 11, 13, 'Federal_Reserve'),
#  ('1144-004', 11, 12, '--NME--'),
#  ('1132-007', 23, 24, 'Mexico'),
#  ('0952-005', 4, 5, 'FC_Rotor_Volgograd'),
#  ('0962-008', 4, 6, 'Duffy_Waldorf'),
#  ('1064-003', 17, 18, 'Saracens_F.C.'),
#  ('0966-049', 4, 5, 'Netherlands'),
#  ('1126-009', 7, 8, 'Islam'),
#  ('0979-002', 22, 23, 'United_States'),
#  ('0972-012', 3, 4, 'Arjuna_Ranatunga'),
#  ('1137-005', 9, 11, 'South_Korea'),
#  ('1064-002', 9, 10, 'England'),
#  ('0984-019', 0, 1, '--NME--'),
#  ('0958-017', 0, 2, 'Kansas_City_Royals'),
#  ('1121-003', 36, 37, 'Kurdistan'),
#  ('1155-014', 5, 6, 'Iran'),
#  ('0966-057', 1, 3, 'Vladimir_Dubrovshchik'),
#  ('0948-009', 6, 8, 'British_Universities_cricket_team'),
#  ('1054-010', 6, 7, 'Team_Jumbo–Visma'),
#  ('1058-031', 12, 14, 'Mark_McGwire'),
#  ('1069-013', 0, 1, 'Warwickshire_County_Cricket_Club'),
#  ('0997-005', 19, 20, 'Boris_Yeltsin'),
#  ('0946-003', 24, 25, 'Kent_County_Cricket_Club'),
#  ('1136-000', 3, 4, 'China'),
#  ('0962-007', 1, 3, 'Bob_Estes'),
#  ('0958-028', 3, 4, 'Los_Angeles_Angels'),
#  ('0966-086', 4, 5, 'United_States'),
#  ('1136-007', 7, 8, 'Caltex'),
#  ('1053-003', 19, 21, '--NME--'),
#  ('0996-007', 8, 9, 'Yugoslavia'),
#  ('1094-028', 0, 1, 'Cleveland_Indians'),
#  ('0947-006', 0, 1, 'Chester-le-Street'),
#  ('1120-002', 19, 20, 'Sudan'),
#  ('0993-004', 21, 22, 'Batajnica'),
#  ('0947-009', 2, 3, 'Sussex_County_Cricket_Club'),
#  ('1116-005', 11, 12, 'England'),
#  ('1008-013', 1, 3, 'Dow_Jones_Industrial_Average'),
#  ('1155-011', 15, 16, 'Berlin'),
#  ('1003-002', 5, 7, '--NME--'),
#  ('1006-001', 0, 2, 'Mona_Eltahawy'),
#  ('0967-005', 25, 27, '--NME--'),
#  ('0966-021', 4, 5, 'United_States'),
#  ('1027-016', 3, 4, 'Jordan'),
#  ('1044-004', 15, 16, 'Yasser_Arafat'),
#  ('1094-047', 0, 1, 'Colorado_Rockies'),
#  ('1115-003', 26, 27, 'Northern_Ireland'),
#  ('0966-155', 4, 5, 'Finland'),
#  ('1137-004', 0, 1, '--NME--'),
#  ('0948-015', 4, 6, '--NME--'),
#  ('1067-001', 0, 1, 'Glasgow'),
#  ('0957-002', 3, 7, 'US_Open_(tennis)'),
#  ('1139-000', 0, 1, 'China'),
#  ('1123-000', 2, 4, 'South_Korea'),
#  ('1146-004', 25, 26, '--NME--'),
#  ('1022-002', 0, 1, 'Canada'),
#  ('1105-003', 0, 1, 'Spain'),
#  ('1016-005', 1, 2, 'State_of_Palestine'),
#  ('1072-003', 28, 30, 'Ellis_Park_Stadium'),
#  ('1120-002', 1, 2, 'Iraq'),
#  ('1097-001', 0, 2, '--NME--'),
#  ('0962-008', 10, 11, 'Sweden'),
#  ('1046-009', 12, 13, 'FIFA'),
#  ('1128-002', 10, 11, '--NME--'),
#  ('0980-013', 7, 8, 'United_States'),
#  ('0986-006', 2, 3, 'Gary_Breen'),
#  ('0982-005', 1, 3, '--NME--'),
#  ('1033-003', 7, 14, '--NME--'),
#  ('0960-002', 0, 2, 'New_York_City'),
#  ('1066-049', 0, 1, 'Luton_Town_F.C.'),
#  ('1083-000', 4, 5, '--NME--'),
#  ('1014-001', 2, 3, 'California'),
#  ('0966-052', 4, 5, 'Republic_of_Ireland'),
#  ('1069-003', 3, 4, 'Middlesex_County_Cricket_Club'),
#  ('1112-004', 18, 19, 'UEFA_European_Championship'),
#  ('1099-017', 17, 19, 'Stephan_Marasek'),
#  ('1157-004', 10, 11, 'Iraq'),
#  ('1068-005', 0, 1, 'Bradford_City_A.F.C.'),
#  ('1153-007', 14, 16, 'Marc_Dutroux'),
#  ('0946-004', 2, 3, 'Somerset_County_Cricket_Club'),
#  ('1135-015', 1, 2, 'National_League_for_Democracy'),
#  ('1011-007', 28, 29, 'Midwestern_United_States'),
#  ('1135-002', 0, 1, 'Yangon'),
#  ('1096-035', 4, 5, 'New_York_Mets'),
#  ('1123-013', 0, 1, '--NME--'),
#  ('1011-023', 40, 42, '--NME--'),
#  ('1138-000', 0, 1, 'China'),
#  ('1103-020', 2, 3, 'Belgium_national_football_team'),
#  ('1058-014', 9, 12, 'American_League_Central'),
#  ('1027-014', 8, 9, 'Yasser_Arafat'),
#  ('1121-008', 3, 4, 'Iraq'),
#  ('1074-000', 7, 8, '--NME--'),
#  ('1125-011', 0, 1, 'Democratic_Republic_of_the_Congo'),
#  ('0965-012', 13, 14, 'Dennis_Mitchell'),
#  ('0946-011', 0, 1, 'Derbyshire_County_Cricket_Club'),
#  ('1140-005', 17, 18, 'Taiwan'),
#  ('1072-007', 1, 3, 'André_Joubert'),
#  ('1119-006', 15, 17, 'Gulf_War'),
#  ('1096-043', 0, 1, 'Donne_Wall'),
#  ('0946-002', 3, 5, 'Phil_Simmons'),
#  ('1079-002', 3, 6, '--NME--'),
#  ('0973-002', 22, 25, '1996_Singer_World_Series'),
#  ('1000-018', 29, 30, '--NME--'),
#  ('1057-006', 32, 34, 'Dean_Headley'),
#  ('0958-036', 0, 2, 'New_York_Yankees'),
#  ('1103-015', 67, 69, 'Luc_Nilis'),
#  ('1047-000', 3, 4, 'Wigan_Warriors'),
#  ('1158-002', 7, 8, 'AK-47'),
#  ('1027-010', 5, 6, 'Jerusalem'),
#  ('1056-034', 16, 17, 'France'),
#  ('1135-003', 4, 8, 'Aung_San_Suu_Kyi'),
#  ('0952-000', 7, 8, 'FC_Volgograd'),
#  ('0966-136', 1, 3, 'Paul_Koech'),
#  ('1031-007', 7, 8, 'Pirelli'),
#  ('1027-006', 12, 13, '--NME--'),
#  ('1012-008', 4, 5, 'Libya'),
#  ('1072-019', 82, 84, 'Sean_Fitzpatrick'),
#  ('0993-006', 20, 22, '--NME--'),
#  ('0998-004', 3, 4, 'Aslan_Maskhadov'),
#  ('1033-003', 15, 16, '--NME--'),
#  ('1132-005', 0, 1, '--NME--'),
#  ('0972-013', 0, 2, '--NME--'),
#  ('1132-003', 24, 25, 'Morelia'),
#  ('0966-147', 1, 3, 'Armen_Martirosyan_(athlete)'),
#  ('0966-146', 1, 3, 'Mike_Conley_Sr.'),
#  ('0960-020', 12, 13, '--NME--'),
#  ('1066-015', 0, 1, 'Portsmouth_F.C.'),
#  ('1006-004', 44, 45, 'Scotland'),
#  ('1011-011', 2, 3, '--NME--'),
#  ('1142-009', 1, 2, 'United_Nations'),
#  ('0972-011', 5, 6, 'Upul_Chandana'),
#  ('0952-001', 0, 1, 'Moscow'),
#  ('1094-043', 0, 1, 'Pittsburgh_Pirates'),
#  ('1034-004', 13, 14, 'Netherlands'),
#  ('0965-003', 8, 10, 'Donovan_Bailey'),
#  ('1130-002', 8, 11, '--NME--'),
#  ('0947-009', 13, 15, '--NME--'),
#  ('1116-038', 3, 6, 'Flag_of_the_United_States'),
#  ('1014-009', 21, 22, 'Bob_Dole'),
#  ('1056-023', 1, 3, '--NME--'),
#  ('0980-014', 0, 2, 'Federal_Reserve'),
#  ('0966-164', 1, 3, '--NME--'),
#  ('1156-000', 0, 1, 'Italy'),
#  ('0965-011', 31, 32, 'Berlin'),
#  ('1039-014', 11, 14, '--NME--'),
#  ('0946-006', 28, 29, 'Headingley'),
#  ('1069-015', 15, 17, '--NME--'),
#  ('1131-001', 0, 1, 'Santiago'),
#  ('1058-026', 1, 2, 'Baltimore_Orioles'),
#  ('1070-006', 1, 3, 'Alex_Zanardi'),
#  ('1072-006', 22, 24, '--NME--'),
#  ('0957-019', 21, 23, 'Åsa_Svensson'),
#  ('1000-014', 23, 24, 'France'),
#  ('1152-014', 9, 10, '--NME--'),
#  ('1127-015', 7, 8, 'Chechnya'),
#  ('1125-006', 0, 1, 'United_Nations'),
#  ('1096-031', 4, 6, 'Marvin_Benard'),
#  ('1097-004', 7, 8, '--NME--'),
#  ('0966-017', 4, 5, 'Germany'),
#  ('1070-013', 1, 3, 'Al_Unser_Jr.'),
#  ('1069-010', 5, 7, '--NME--'),
#  ('1101-011', 82, 84, 'Patrice_Loko'),
#  ('0967-005', 7, 8, '--NME--'),
#  ('0966-139', 4, 5, 'Morocco'),
#  ('1027-009', 18, 19, 'Islam'),
#  ('1103-003', 22, 23, '--NME--'),
#  ('1008-023', 8, 9, 'CNBC'),
#  ('1089-007', 0, 2, 'Tiger_Woods'),
#  ('1134-000', 2, 3, 'Indonesia'),
#  ('1147-006', 7, 8, 'Iraq'),
#  ('1147-006', 19, 20, 'United_Nations'),
#  ('1155-002', 0, 1, 'Iran'),
#  ('0966-010', 4, 5, 'Jamaica'),
#  ('1047-001', 2, 3, 'England'),
#  ('0963-022', 2, 4, 'Scott_Hoch'),
#  ('1096-036', 26, 28, 'Colorado_Rockies'),
#  ('1083-002', 4, 5, '--NME--'),
#  ('1011-007', 3, 4, '--NME--'),
#  ('1060-012', 4, 5, 'Australia'),
#  ('1001-003', 20, 21, '--NME--'),
#  ('0986-006', 12, 13, 'Alan_McLoughlin'),
#  ('1117-005', 27, 28, 'London'),
#  ('1130-005', 36, 39, '--NME--'),
#  ('0990-002', 23, 25, 'Alexander_Lebed'),
#  ('0956-002', 2, 4, 'South_Korea'),
#  ('0992-002', 29, 30, 'United_States'),
#  ('0966-074', 1, 3, 'Rose_Cheruiyot'),
#  ('1096-032', 9, 10, 'New_York_Mets'),
#  ('1115-003', 14, 15, 'Margaret_Thatcher'),
#  ('1046-009', 3, 4, 'Deportivo_de_La_Coruña'),
#  ('1159-003', 19, 20, 'Reuters'),
#  ('1089-010', 17, 18, '--NME--'),
#  ('1079-001', 0, 1, 'Belgrade'),
#  ('0985-007', 1, 3, '--NME--'),
#  ('0970-003', 1, 4, 'La_Gazzetta_dello_Sport'),
#  ('1096-020', 22, 23, 'Atlanta_Braves'),
#  ('1112-004', 4, 5, 'Germany_national_football_team'),
#  ('1073-002', 3, 5, 'New_Zealand_national_rugby_union_team'),
#  ('1025-009', 18, 19, 'Israel'),
#  ('1039-007', 0, 1, 'Indonesia'),
#  ('0957-016', 11, 13, 'Czech_Republic'),
#  ('1064-007', 47, 48, 'Bristol_Bears'),
#  ('0993-002', 23, 24, 'Yugoslavia'),
#  ('1116-013', 1, 2, 'Liberal_Party_(UK)'),
#  ('1099-018', 17, 19, '--NME--'),
#  ('0962-008', 1, 3, 'Billy_Andrade'),
#  ('1115-004', 2, 3, 'Margaret_Thatcher'),
#  ('1151-006', 20, 21, 'Dallas'),
#  ('0966-032', 1, 3, 'Ato_Boldon'),
#  ('1054-018', 1, 2, 'Viatcheslav_Ekimov'),
#  ('0966-061', 4, 5, 'Germany'),
#  ('1009-009', 18, 19, 'California'),
#  ('1035-009', 0, 1, 'Russia'),
#  ('1025-006', 3, 5, '--NME--'),
#  ('1073-004', 0, 2, 'South_Africa_national_rugby_union_team'),
#  ('0949-010', 6, 8, 'Teddy_Sheringham'),
#  ('1027-023', 1, 3, '--NME--'),
#  ('1003-003', 36, 37, 'Moengo'),
#  ('1095-015', 2, 3, 'Cincinnati_Reds'),
#  ('1065-018', 0, 3, '--NME--'),
#  ('1009-002', 0, 1, 'Washington,_D.C.'),
#  ('0981-001', 0, 2, 'Farmington_Hills,_Michigan'),
#  ('1123-004', 2, 3, '--NME--'),
#  ('0957-001', 0, 2, 'New_York_City'),
#  ('0948-027', 6, 7, 'Derbyshire_County_Cricket_Club'),
#  ('1057-006', 2, 4, 'Michael_Atherton'),
#  ('0954-002', 24, 26, 'Mark_Cairns_(squash_player)'),
#  ('1144-002', 38, 39, 'Baghdad'),
#  ('1020-000', 0, 1, 'India'),
#  ('0965-004', 28, 29, 'Donovan_Bailey'),
#  ('1043-001', 0, 1, 'Singapore'),
#  ('1075-000', 5, 6, 'Benin_national_football_team'),
#  ('1109-005', 0, 1, 'Netherlands_national_football_team'),
#  ('0960-003', 0, 2, 'Andre_Agassi'),
#  ('1064-004', 10, 11, 'Michael_Lynagh'),
#  ('0994-017', 16, 18, '--NME--'),
#  ('1146-005', 35, 37, 'Saddam_Hussein'),
#  ('1007-003', 1, 3, 'New_York_Stock_Exchange'),
#  ('1107-000', 6, 7, 'Scotland_national_football_team'),
#  ('1152-001', 0, 2, '--NME--'),
#  ('1096-033', 8, 10, 'Rod_Beck'),
#  ('0974-004', 5, 6, '--NME--'),
#  ('1096-029', 4, 5, 'Montreal_Expos'),
#  ('1111-009', 0, 1, 'United_Kingdom'),
#  ('0966-058', 4, 5, 'Lithuania'),
#  ('0997-006', 5, 6, 'Moscow'),
#  ('0949-011', 6, 7, 'Alan_Shearer'),
#  ('0995-006', 0, 1, '--NME--'),
#  ('1067-008', 7, 9, 'St_Johnstone_F.C.'),
#  ('1027-007', 33, 35, '--NME--'),
#  ('0949-004', 16, 17, 'Moldova_national_football_team'),
#  ('1060-003', 8, 10, 'Robert_Allenby'),
#  ('1116-021', 0, 1, 'United_Kingdom'),
#  ('1119-005', 11, 12, 'Iraq'),
#  ('1127-009', 9, 10, 'Chechnya'),
#  ('1076-006', 2, 3, 'FK_Rad'),
#  ('1137-008', 33, 34, 'Korea'),
#  ('1096-013', 25, 28, 'Los_Angeles_Dodgers'),
#  ('0963-006', 15, 16, 'Tiger_Woods'),
#  ('1161-005', 1, 3, '--NME--'),
#  ('1072-019', 41, 43, 'Justin_Marshall'),
#  ('1132-003', 11, 12, 'Michoacán'),
#  ('1030-030', 13, 14, 'Bill_Clinton'),
#  ('0980-004', 4, 5, 'Eurodollar'),
#  ('1119-007', 7, 8, 'France'),
#  ('1090-013', 14, 15, 'Billie_Jean_King'),
#  ('1055-008', 0, 2, '--NME--'),
#  ('1125-008', 21, 22, 'Rwanda'),
#  ('1096-041', 3, 5, 'Sean_Berry'),
#  ('1152-003', 15, 17, 'Bill_Clinton'),
#  ('0973-000', 8, 10, 'Sri_Lanka_national_cricket_team'),
#  ('1094-054', 3, 4, 'Philadelphia_Phillies'),
#  ('1116-007', 13, 15, 'Charles_VI,_Holy_Roman_Emperor'),
#  ('0995-002', 0, 1, 'Tavildara'),
#  ('1054-013', 1, 3, 'Michael_Andersson'),
#  ('0947-009', 21, 23, '--NME--'),
#  ('1133-003', 0, 2, 'Xiao_Qiang'),
#  ('1060-018', 4, 5, 'Republic_of_Ireland'),
#  ('1056-016', 20, 21, 'Russia'),
#  ('0957-018', 35, 36, 'Switzerland'),
#  ('1026-001', 0, 1, 'Cairo'),
#  ('1143-002', 21, 22, 'Israel'),
#  ('1079-007', 2, 3, 'Germany'),
#  ('0962-003', 4, 7, 'Greater_Milwaukee_Open'),
#  ('1070-015', 1, 3, 'Maurício_Gugelmin'),
#  ('1066-018', 0, 2, 'Port_Vale_F.C.'),
#  ('1058-035', 3, 4, 'Boston_Red_Sox'),
#  ('1067-018', 0, 1, 'Arbroath_F.C.'),
#  ('0975-004', 0, 1, '--NME--'),
#  ('1101-008', 16, 18, 'Inter_Milan'),
#  ('0972-020', 2, 3, '--NME--'),
#  ('1005-010', 18, 20, 'New_York_City'),
#  ('1058-030', 7, 8, '--NME--'),
#  ('1116-003', 3, 5, 'Elizabeth_I_of_England'),
#  ('1133-002', 8, 9, 'China'),
#  ('1129-002', 17, 18, 'Moscow'),
#  ('1073-006', 7, 8, '--NME--'),
#  ('1046-000', 2, 3, 'Real_Madrid_CF'),
#  ('0985-007', 10, 11, 'The_Sun_(United_Kingdom)'),
#  ('1152-017', 10, 14, '--NME--'),
#  ('0996-008', 0, 1, 'Poland'),
#  ('0966-083', 1, 3, 'Derrick_Adkins'),
#  ('1072-012', 34, 37, '--NME--'),
#  ('0970-002', 27, 29, 'Serie_A'),
#  ('1030-004', 3, 4, 'London'),
#  ('1152-018', 18, 19, 'United_States'),
#  ('0984-013', 7, 11, 'Chicago_Board_of_Trade'),
#  ('1069-017', 9, 11, '--NME--'),
#  ('1013-002', 8, 10, '--NME--'),
#  ('1095-013', 2, 3, 'Atlanta_Braves'),
#  ('0983-000', 0, 1, 'Iraq'),
#  ('0984-017', 18, 20, 'Labor_Day'),
#  ('1015-002', 20, 22, 'RMS_Titanic'),
#  ('1069-014', 0, 1, 'Surrey_County_Cricket_Club'),
#  ('1128-003', 17, 18, 'Poland'),
#  ('1006-007', 9, 10, 'Ghana'),
#  ('1014-003', 9, 10, 'Bill_Clinton'),
#  ('1008-024', 20, 21, 'Lawrence_B._Lindsey'),
#  ('1061-018', 0, 1, 'Boroughmuir_RFC'),
#  ('1160-007', 21, 22, 'Neil_Jordan'),
#  ('1008-018', 8, 9, 'Philadelphia'),
#  ('1039-014', 15, 17, 'South_Korea'),
#  ('0957-033', 12, 13, 'United_States'),
#  ('1142-013', 1, 2, 'Iraq'),
#  ('1062-000', 4, 6, 'San_Marino_national_football_team'),
#  ('1088-002', 46, 47, 'Scotland'),
#  ('0990-002', 31, 32, 'Interfax'),
#  ('1007-011', 0, 1, 'Bill_Clinton'),
#  ('0948-036', 6, 8, 'Old_Trafford_Cricket_Ground'),
#  ('1077-000', 5, 6, 'Paul_Gascoigne'),
#  ('1096-002', 2, 3, '--NME--'),
#  ('1030-033', 0, 1, 'Dick_Morris'),
#  ('1096-038', 0, 2, '--NME--'),
#  ('1056-017', 5, 7, 'Philippe_Ermenault'),
#  ('1000-014', 6, 7, 'Hungary'),
#  ('0986-006', 4, 5, 'Steve_Staunton'),
#  ('1060-008', 1, 3, 'Lee_Westwood'),
#  ('1124-000', 2, 3, '--NME--'),
#  ('1039-011', 29, 30, 'Moro_National_Liberation_Front'),
#  ('0959-005', 2, 4, 'Kansas_City_Royals'),
#  ('0961-001', 0, 1, 'Philadelphia'),
#  ('1072-005', 28, 30, 'New_Zealand_national_rugby_union_team'),
#  ('0983-001', 0, 1, 'London'),
#  ('1009-007', 16, 17, 'Mexico'),
#  ('1009-010', 0, 1, 'California'),
#  ('1127-026', 3, 4, 'Islam'),
#  ('1146-005', 48, 49, 'Iran'),
#  ('1009-003', 17, 19, 'United_States'),
#  ('1038-004', 0, 2, 'Hong_Kong'),
#  ('0981-017', 2, 4, 'Johnson_Controls'),
#  ('1103-016', 41, 43, 'Tolunay_Kafkas'),
#  ('1083-002', 6, 7, 'Russia'),
#  ('0984-002', 11, 12, 'Europe'),
#  ('0956-017', 0, 1, '--NME--'),
#  ('1048-003', 11, 13, '--NME--'),
#  ('1126-005', 0, 1, '--NME--'),
#  ('0957-009', 9, 11, 'Czech_Republic'),
#  ('1008-023', 14, 16, 'Lawrence_B._Lindsey'),
#  ('1125-003', 1, 11, '--NME--'),
#  ('0952-003', 20, 22, 'FC_Lada-Tolyatti'),
#  ('1118-001', 0, 1, 'Stirling'),
#  ('0991-006', 4, 5, 'Aslan_Maskhadov'),
#  ('0963-021', 15, 17, 'Billy_Mayfair'),
#  ('0997-004', 27, 28, 'Moscow'),
#  ('0972-030', 0, 2, '--NME--'),
#  ('1084-003', 7, 9, 'Daniel_Andersson_(footballer,_born_1977)'),
#  ('0948-039', 3, 4, 'Glamorgan_County_Cricket_Club'),
#  ('1058-025', 0, 2, 'Jay_Buhner'),
#  ('1007-017', 11, 12, 'Bill_Clinton'),
#  ('0967-003', 17, 19, 'Guy_Hellers'),
#  ('0982-001', 0, 1, 'London'),
#  ('1138-003', 17, 18, '--NME--'),
#  ('0948-046', 9, 10, 'London'),
#  ('1003-003', 18, 19, 'Netherlands'),
#  ('0972-036', 6, 7, 'Stuart_Law'),
#  ('0948-032', 6, 8, '--NME--'),
#  ('0987-000', 0, 1, 'Nigeria'),
#  ('1032-006', 21, 22, '--NME--'),
#  ('0949-005', 22, 23, 'Blackburn_Rovers_F.C.'),
#  ('1066-036', 0, 1, 'Shrewsbury_Town_F.C.'),
#  ('1111-000', 3, 5, '--NME--'),
#  ('1131-002', 13, 14, 'Chile'),
#  ('1090-017', 12, 13, 'Lindsay_Davenport'),
#  ('0965-001', 0, 2, '--NME--'),
#  ('1073-009', 2, 3, 'Andrew_Mehrtens'),
#  ('1033-010', 10, 11, '--NME--'),
#  ('0966-047', 1, 3, 'William_Tanui'),
#  ('1138-011', 0, 1, 'China'),
#  ('0966-079', 1, 3, 'Sally_Barsosio'),
#  ('1068-025', 0, 1, 'Shrewsbury_Town_F.C.'),
#  ('1112-003', 33, 35, 'Süddeutsche_Zeitung'),
#  ('1127-026', 1, 2, '--NME--'),
#  ('0947-010', 2, 3, 'Middlesex_County_Cricket_Club'),
#  ('0962-009', 13, 15, 'Willie_Wood_(golfer)'),
#  ('1000-003', 16, 17, 'Budapest_Stock_Exchange'),
#  ('1009-003', 7, 8, 'Mexico'),
#  ('1012-008', 19, 20, '--NME--'),
#  ('1097-000', 2, 3, 'Stefan_Edberg'),
#  ('1056-030', 4, 5, 'United_Kingdom'),
#  ('0997-005', 17, 18, 'Sergey_Yastrzhembsky'),
#  ('1098-002', 0, 1, 'United_Kingdom'),
#  ('1009-001', 0, 2, '--NME--'),
#  ('1148-009', 4, 6, 'Habib_Boularès'),
#  ('0966-052', 1, 3, '--NME--'),
#  ('1142-005', 13, 16, 'Kurdistan_Democratic_Party'),
#  ('1096-040', 0, 2, 'Eric_Anthony'),
#  ('1025-006', 0, 1, 'State_of_Palestine'),
#  ('1120-000', 1, 2, 'Iraq'),
#  ('1160-023', 18, 20, 'Michael_Collins_(film)'),
#  ('1147-002', 13, 14, 'Iraq'),
#  ('1072-018', 49, 51, 'Gary_Teichmann'),
#  ('1148-001', 0, 1, 'Tunis'),
#  ('0953-002', 3, 10, '--NME--'),
#  ('1121-003', 5, 8, 'Iraqi_National_Congress'),
#  ('0969-000', 2, 3, 'Dominique_Baratelli'),
#  ('0966-159', 4, 5, 'Lithuania'),
#  ('1077-006', 0, 1, 'England_national_football_team'),
#  ('1152-007', 31, 32, 'Iraq'),
#  ('1135-026', 0, 2, 'Aung_San_Suu_Kyi'),
#  ('0960-010', 8, 10, 'New_Haven,_Connecticut'),
#  ('0970-000', 7, 8, 'Atalanta_B.C.'),
#  ('0957-026', 0, 2, 'Andriy_Medvedev'),
#  ('0968-000', 8, 9, 'Sarajevo'),
#  ('0984-006', 4, 6, 'United_States_Treasury_security'),
#  ('1046-010', 11, 12, '--NME--'),
#  ('1066-042', 0, 2, 'Bristol_Rovers_F.C.'),
#  ('1026-004', 0, 1, 'Akhbar'),
#  ('1067-013', 2, 3, 'Brechin_City_F.C.'),
#  ('1090-011', 10, 12, 'Monica_Seles'),
#  ('1110-000', 2, 3, 'Nate_Miller'),
#  ('1033-008', 9, 11, 'Aslan_Maskhadov'),
#  ('1103-006', 10, 12, '--NME--'),
#  ('1030-001', 0, 2, 'New_York_City'),
#  ('1067-008', 2, 4, 'East_Fife_F.C.'),
#  ('1094-020', 0, 1, 'Seattle_Mariners'),
#  ('1101-001', 0, 1, 'Paris'),
#  ('1064-003', 28, 30, '--NME--'),
#  ('1012-006', 29, 30, 'Louis_Farrakhan'),
#  ('1058-028', 0, 1, 'Frank_Thomas_(designated_hitter)'),
#  ('0957-006', 8, 10, 'Scott_Draper'),
#  ('0956-010', 4, 5, '--NME--'),
#  ('0966-095', 1, 3, 'Phylis_Smith'),
#  ('1093-004', 0, 1, "United_States_men's_national_soccer_team"),
#  ('1142-005', 9, 11, '--NME--'),
#  ('1011-013', 5, 6, 'Norwest'),
#  ('1116-017', 12, 13, '--NME--'),
#  ('0946-014', 12, 13, '--NME--'),
#  ('1137-008', 2, 3, 'Yonhap_News_Agency'),
#  ('0966-078', 1, 3, 'Pauline_Konga'),
#  ('0966-161', 7, 9, 'Michael_Johnson_(sprinter)'),
#  ('1135-029', 6, 7, 'Myanmar'),
#  ('1099-017', 28, 30, 'Dietmar_Kühbauer'),
#  ('1101-003', 34, 35, 'Chelsea_F.C.'),
#  ('1022-007', 13, 14, '--NME--'),
#  ('1071-000', 2, 3, '--NME--'),
#  ('0984-020', 0, 1, '--NME--'),
#  ('1066-079', 0, 1, 'Mansfield_Town_F.C.'),
#  ('0948-025', 5, 6, 'Sussex_County_Cricket_Club'),
#  ('1003-003', 10, 12, '--NME--'),
#  ('1068-033', 2, 3, 'Barnet_F.C.'),
#  ('0998-002', 0, 1, 'Russia'),
#  ('1099-018', 0, 1, 'Scotland_national_football_team'),
#  ('1044-003', 3, 4, 'Yasser_Arafat'),
#  ('1072-018', 68, 70, '--NME--'),
#  ('1085-002', 13, 14, 'Europe'),
#  ('0949-005', 24, 25, 'Southampton_F.C.'),
#  ('0964-003', 5, 6, 'Brazil'),
#  ('1068-008', 2, 3, 'Wolverhampton_Wanderers_F.C.'),
#  ('1066-032', 0, 1, 'Brentford_F.C.'),
#  ('0998-003', 5, 6, 'Chechnya'),
#  ('0984-009', 9, 10, 'Paris'),
#  ('1133-013', 16, 17, '--NME--'),
#  ('0946-007', 5, 6, 'England_cricket_team'),
#  ...}

# %%
list(df_dev_small.loc[df_dev_small.sentence_id=='0962-001'].values)
# Out:
# [array(['0962-001', 'MILWAUKEE , Wisconsin 1996-08-29', 2, 3, '--NME--'],
#        dtype=object),
#  array(['0962-001', 'MILWAUKEE , Wisconsin 1996-08-29', 0, 1, '--NME--'],
#        dtype=object)]

# %%
evaluation_report(mentions_dev_gold,x)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-33-ea99f96f43fe> in <module>
# ----> 1 evaluation_report(mentions_dev_gold,x)
#
# <ipython-input-6-9bc0f5de7513> in evaluation_report(gold, pred)
#      17     precision = len(intersection)/len(pred)
#      18     recall = len(intersection)/len(gold)
# ---> 19     f1 = (2*(precision*recall))/(precision+recall)
#      20     print("Precision :{:.0%}, Recall :{:.0%},F1-value :{:.0%}".format(precision,recall,f1))
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# ## Problem 5: Extending the training data using the knowledge base

# %% [markdown]
# State-of-the-art approaches to entity linking exploit information in knowledge bases. In our case, where Wikipedia is the knowledge base, one particularly useful type of information are links to other Wikipedia pages. In particular, we can interpret the anchor texts (the highlighted texts that you click on when you click on a link) as mentions of the entities (pages) that they link to. This allows us to harvest long lists over mention–entity pairings.
#
# The following cell loads a data frame summarizing anchor texts and page references harvested from the first paragraphs of the English Wikipedia. The data frame also contains all entity mentions in the training data (but not the development or the test data).

# %%
with bz2.open("kb.tsv.bz2", 'rt') as source:
    df_kb = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# To understand what information is available in this data, the following cell shows the entry for the anchor text `Sweden`.

# %%
df_kb.loc[df_kb["mention"] == "Sweden"]
# Out:
#       mention                                 entity      prob
# 17436  Sweden                                 Sweden  0.985768
# 17437  Sweden          Sweden_national_football_team  0.014173
# 17438  Sweden  Sweden_men's_national_ice_hockey_team  0.000059

# %% [markdown]
# As you can see, each row of the data frame contains a pair $(m, e)$ of a mention $m$ and an entity $e$, as well as the conditional probability $P(e|m)$ for mention $m$ referring to entity $e$. These probabilities were estimated based on the frequencies of mention–entity pairs in the knowledge base. The example shows that the anchor text &lsquo;Sweden&rsquo; is most often used to refer to the entity [Sweden](http://en.wikipedia.org/wiki/Sweden), but in a few cases also to refer to Sweden&rsquo;s national football and ice hockey teams. Note that references are sorted in decreasing order of probability, so that the most probable pairing stands first.
#
# Implement an entity linking method that resolves each mention to the most probable entity in the data frame. If the mention is not included in the data frame, you can predict the generic label `--NME--`. Print the precision, recall, and F1 of your method using the function that you implemented for Problem&nbsp;1.

# %%
# TODO: Write code here to implement the "most probable entity" method.
test = []
for i in df_kb["mention"]:
    #print("--- Start ---")
    
    max_prob = list(df_kb.loc[df_kb["mention"] == i, "entity"])
    
    if max_prob: # check if 
        enter = max_prob[0]   
    else:
        enter = "-NME-"
    test.append(enter)
    if enter == '-NME-' :
        print(enter)
        print("\n")
        print(max_prob)
    
    #print("--- End ---")
# Out:
# -NME-
#
#
# []

# %%
df_kb.

# %% [markdown]
# ## Problem 6: Context-sensitive disambiguation

# %% [markdown]
# Consider the entity mention &lsquo;Lincoln&rsquo;. The most probable entity for this mention turns out to be [Lincoln, Nebraska](http://en.wikipedia.org/Lincoln,_Nebraska); but in pages about American history, we would be better off to predict [Abraham Lincoln](http://en.wikipedia.org/Abraham_Lincoln). This suggests that we should try to disambiguate between different entity references based on the textual context on the page from which the mention was taken. Your task in this last problem is to implement this idea.
#
# Set up a dictionary that contains, for each mention $m$ that can refer to more than one entity $e$, a separate Naive Bayes classifier to predict the correct entity $e$, given the textual context of the mention. As the prior probabilities of the classifier, choose the probabilities $P(e|m)$ that you used in Problem&nbsp;5. To let you estimate the context-specific probabilities, we have compiled a data set with mention contexts:

# %%
with bz2.open("contexts.tsv.bz2") as source:
    df_contexts = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# This data frame contains, for each ambiguous mention $m$ and each knowledge base entity $e$ to which this mention can refer, up to 100 randomly selected contexts in which $m$ is used to refer to $e$. For this data, a **context** is defined as a bag of words containing the mention itself, as well as the 5 tokens to the left and the 5 tokens to the right of the mention. Here are a few examples:

# %%
df_contexts.head()
# Out:
#           mention                 entity  \
# 0            1970  UEFA_Champions_League
# 1            1970         FIFA_World_Cup
# 2  1990 World Cup    1990_FIFA_World_Cup
# 3  1990 World Cup    1990_FIFA_World_Cup
# 4  1990 World Cup    1990_FIFA_World_Cup
#
#                                              context
# 0  Cup twice the first in 1970 and the second in ...
# 1  America 1975 and during the 1970 and 1978 Worl...
# 2     Manolo represented Spain at the 1990 World Cup
# 3  Hašek represented Czechoslovakia at the 1990 W...
# 4  renovations in 1989 for the 1990 World Cup The...

# %% [markdown]
# From this data frame, it is easy to select the data that you need to train the classifiers – the contexts and corresponding entities for all mentions. To illustrate this, the following cell shows how to select all contexts that belong to the mention &lsquo;Lincoln&rsquo;:

# %%
df_contexts.context[df_contexts.mention == "Lincoln"]
# Out:
# 41465    Nebraska Concealed Handgun Permit In Lincoln m...
# 41466    Lazlo restaurants are located in Lincoln and O...
# 41467    California Washington Overland Park Kansas Lin...
# 41468    City Missouri Omaha Nebraska and Lincoln Nebra...
# 41469    by Sandhills Publishing Company in Lincoln Neb...
#                                ...
# 41609                                Lincoln Leyton Orient
# 41610               English division three Swansea Lincoln
# 41611    league membership narrowly edging out Lincoln ...
# 41612                                    Lincoln Cambridge
# 41613                                              Lincoln
# Name: context, Length: 149, dtype: object

# %% [markdown]
# Implement the context-sensitive disambiguation method and evaluate its performance. Here are some more hints that may help you along the way:
#
# **Hint 1:** The prior probabilities for a Naive Bayes classifier can be specified using the `class_prior` option. You will have to provide the probabilities in the same order as the alphabetically sorted class (entity) names.
#
# **Hint 2:** To tune the performance of your method, you can try to tweak the behaviour of the vectorizer (for example, should it apply lowercasing or not?) and the width of the window from which you are extracting context tokens at prediction time.
#
# **Hint 3:** Not all mentions in the knowledge base are ambiguous, and therefore not all mentions have context data. If a mention has only one possible entity, pick that one. If a mention has no entity at all, predict the `--NME--` label.

# %%
# TODO: Write code here to implement the context-sensitive disambiguation method

# %% [markdown]
# You should expect to see a small (around 1&nbsp;unit) increase in both precision, recall, and F1. Published systems report a larger impact of context-sensitive disambiguation. Feel free to think about what could explain the relatively minor impact that we see here!

# %% [markdown]
# **This was the last lab in the Text Mining course. Well done!**

# %% [markdown]
# <div class="alert alert-info">
#     Please read the section ‘General information’ on the ‘Labs’ page of the course website before submitting this notebook!
# </div>
